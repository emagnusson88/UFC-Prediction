# %% [markdown]
# <h1>Cleaning, EDA, and Feature Engineering after Scraping</h1>
#
# - Acknowledgements:
#     - ufcstats for comprehensive data sets on past MMA bouts: http://ufcstats.com/
#     - Rajeev Warrier for providing the groundwork for this prediction project: https://github.com/WarrierRajeev/UFC-Predictions

# %%
import pandas as pd
import numpy as np

DATA_PATH ='./data'
df_fighters = pd.read_csv(DATA_PATH+'/fighter_details.csv')
df_fights = pd.read_csv(DATA_PATH+'/total_fight_data.csv', sep=';')

# %%
df_fighters.head()
# Out:
#           fighter_name  Height    Weight Reach    Stance           DOB
# 0            Tom Aaron     NaN  155 lbs.   NaN       NaN  Jul 13, 1978
# 1         Danny Abbadi  5' 11"  155 lbs.   NaN  Orthodox  Jul 03, 1983
# 2         David Abbott   6' 0"  265 lbs.   NaN    Switch           NaN
# 3  Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4         Hiroyuki Abe   5' 6"  145 lbs.   NaN  Orthodox           NaN

# %%
df_fights.head(3).T
# Out:
#                                            0  \
# R_fighter                    Israel Adesanya
# B_fighter                        Yoel Romero
# R_KD                                       0
# B_KD                                       0
# R_SIG_STR.                         48 of 132
# B_SIG_STR.                          40 of 89
# R_SIG_STR_pct                            36%
# B_SIG_STR_pct                            44%
# R_TOTAL_STR.                       48 of 132
# B_TOTAL_STR.                        40 of 89
# R_TD                                  0 of 0
# B_TD                                  0 of 3
# R_TD_pct                                  0%
# B_TD_pct                                  0%
# R_SUB_ATT                                  0
# B_SUB_ATT                                  0
# R_PASS                                     0
# B_PASS                                     0
# R_REV                                      0
# B_REV                                      0
# R_HEAD                              14 of 81
# B_HEAD                              20 of 58
# R_BODY                               9 of 22
# B_BODY                               7 of 13
# R_LEG                               25 of 29
# B_LEG                               13 of 18
# R_DISTANCE                         48 of 132
# B_DISTANCE                          35 of 82
# R_CLINCH                              0 of 0
# B_CLINCH                              5 of 7
# R_GROUND                              0 of 0
# B_GROUND                              0 of 0
# win_by                  Decision - Unanimous
# last_round                                 5
# last_round_time                         5:00
# Format                     5 Rnd (5-5-5-5-5)
# Referee                      Dan Miragliotta
# date                          March 07, 2020
# location              Las Vegas, Nevada, USA
# Fight_type       UFC Middleweight Title Bout
# Winner                       Israel Adesanya
#
#                                                   1                       2
# R_fighter                               Weili Zhang          Beneil Dariush
# B_fighter                        Joanna Jedrzejczyk           Drakkar Klose
# R_KD                                              0                       1
# B_KD                                              0                       0
# R_SIG_STR.                               165 of 408                12 of 20
# B_SIG_STR.                               186 of 360                15 of 25
# R_SIG_STR_pct                                   40%                     60%
# B_SIG_STR_pct                                   51%                     60%
# R_TOTAL_STR.                             170 of 413                17 of 28
# B_TOTAL_STR.                             196 of 370                27 of 37
# R_TD                                         1 of 8                  1 of 3
# B_TD                                         0 of 0                  0 of 0
# R_TD_pct                                        12%                     33%
# B_TD_pct                                         0%                      0%
# R_SUB_ATT                                         0                       2
# B_SUB_ATT                                         0                       0
# R_PASS                                            0                       1
# B_PASS                                            0                       0
# R_REV                                             0                       0
# B_REV                                             0                       0
# R_HEAD                                    96 of 305                 8 of 16
# B_HEAD                                    96 of 230                12 of 22
# R_BODY                                     11 of 22                  3 of 3
# B_BODY                                     32 of 47                  0 of 0
# R_LEG                                      58 of 81                  1 of 1
# B_LEG                                      58 of 83                  3 of 3
# R_DISTANCE                               158 of 393                12 of 20
# B_DISTANCE                               171 of 342                13 of 22
# R_CLINCH                                    7 of 15                  0 of 0
# B_CLINCH                                   15 of 18                  2 of 3
# R_GROUND                                     0 of 0                  0 of 0
# B_GROUND                                     0 of 0                  0 of 0
# win_by                             Decision - Split                  KO/TKO
# last_round                                        5                       2
# last_round_time                                5:00                    1:00
# Format                            5 Rnd (5-5-5-5-5)           3 Rnd (5-5-5)
# Referee                              Keith Peterson            Jason Herzog
# date                                 March 07, 2020          March 07, 2020
# location                     Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type       UFC Women's Strawweight Title Bout        Lightweight Bout
# Winner                                  Weili Zhang          Beneil Dariush

# %% [markdown]
# <h3>Processing Fighter data set</h3>

# %%
df_fighters.dtypes
# Out:
# fighter_name    object
# Height          object
# Weight          object
# Reach           object
# Stance          object
# DOB             object
# dtype: object

# %%
df_fighters.isna().sum()
# Out:
# fighter_name       0
# Height           257
# Weight            74
# Reach           1714
# Stance           840
# DOB              741
# dtype: int64

# %% [markdown]
# - fighters with NaN Weight values have little to no useful data
#     - therefore, these rows will be excluded

# %%
df_fighters[pd.isnull(df_fighters['Weight'])]
# Out:
#         fighter_name Height Weight Reach Stance  DOB
# 37       Juan Alcain    NaN    NaN   NaN    NaN  NaN
# 53       Levi Alford    NaN    NaN   NaN    NaN  NaN
# 77     Anthony Alves    NaN    NaN   NaN    NaN  NaN
# 125   Joey Armstrong    NaN    NaN   NaN    NaN  NaN
# 180      Yohan Banks    NaN    NaN   NaN    NaN  NaN
# ...              ...    ...    ...   ...    ...  ...
# 3085     Carl Toomey    NaN    NaN   NaN    NaN  NaN
# 3228  Jeremy Wallace  5' 9"    NaN   NaN    NaN  NaN
# 3304     Karl Willis    NaN    NaN   NaN    NaN  NaN
# 3317      Ray Wizard    NaN    NaN   NaN    NaN  NaN
# 3330    Chris Wright    NaN    NaN   NaN    NaN  NaN
#
# [74 rows x 6 columns]

# %%
df_fighters = df_fighters[df_fighters['Weight'].notna()]

# %% [markdown]
# - to fill NaN values in bodily metrics, find:
#     - average reach for each height increment
#     - average height for each weight increment

# %%
df_fighters['Weight'] = df_fighters['Weight'].apply(lambda x: x.split(' ')[0])
df_fighters['Weight'] = df_fighters['Weight'].astype(float)

# %%
df_fighters['Height'] = df_fighters['Height'].fillna('0\' 0\"')
df_fighters['Height'] = df_fighters['Height'].apply(lambda x: int(x.split('\' ')[0])*12 + int(x.split('\' ')[1].replace('\"','')))
df_fighters['Height'] = df_fighters['Height'].replace(0, np.nan).astype(float)

# %%
df_fighters['Height'] = df_fighters.groupby('Weight')['Height'].apply(lambda x: x.fillna(x.mean()))
df_fighters['Height'] = df_fighters['Height'].fillna(df_fighters['Height'].mean())

# %%
df_fighters['Reach'] = df_fighters['Reach'].fillna('0')
df_fighters['Reach'] = df_fighters['Reach'].apply(lambda x: x.replace('\"',''))
df_fighters['Reach'] = df_fighters['Reach'].replace('0', np.nan).astype(float)

# %%
df_fighters['Reach'] = df_fighters.groupby('Height')['Reach'].apply(lambda x: x.fillna(x.mean()))
df_fighters['Reach'] = df_fighters['Reach'].fillna(df_fighters['Reach'].mean())

# %%
df_fighters['Stance'].value_counts()
# Out:
# Orthodox       1999
# Southpaw        450
# Switch          100
# Open Stance       7
# Sideways          3
# Name: Stance, dtype: int64

# %% [markdown]
# <h3>Processing Fight data set</h3>

# %%
df_fights.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_PASS              int64
# B_PASS              int64
# R_REV               int64
# B_REV               int64
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# Format             object
# Referee            object
# date               object
# location           object
# Fight_type         object
# Winner             object
# dtype: object

# %% [markdown]
# - split attack stats into attempts/landed numerical format

# %%
df_fights.columns
attack_cols = ['R_SIG_STR.', 'B_SIG_STR.','R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY',
       'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
       'B_CLINCH', 'R_GROUND', 'B_GROUND']

# %%
for col in attack_cols:
    df_fights[col+'_ATT'] = df_fights[col].apply(lambda x: int(x.split('of')[1]))
    df_fights[col+'_LANDED'] = df_fights[col].apply(lambda x: int(x.split('of')[0]))

# %%
df_fights.drop(attack_cols, axis=1, inplace=True)

# %%
df_fights.head().T
# Out:
#                                                0  \
# R_fighter                        Israel Adesanya
# B_fighter                            Yoel Romero
# R_KD                                           0
# B_KD                                           0
# R_SIG_STR_pct                                36%
# B_SIG_STR_pct                                44%
# R_TD_pct                                      0%
# B_TD_pct                                      0%
# R_SUB_ATT                                      0
# B_SUB_ATT                                      0
# R_PASS                                         0
# B_PASS                                         0
# R_REV                                          0
# B_REV                                          0
# win_by                      Decision - Unanimous
# last_round                                     5
# last_round_time                             5:00
# Format                         5 Rnd (5-5-5-5-5)
# Referee                          Dan Miragliotta
# date                              March 07, 2020
# location                  Las Vegas, Nevada, USA
# Fight_type           UFC Middleweight Title Bout
# Winner                           Israel Adesanya
# R_SIG_STR._ATT                               132
# R_SIG_STR._LANDED                             48
# B_SIG_STR._ATT                                89
# B_SIG_STR._LANDED                             40
# R_TOTAL_STR._ATT                             132
# R_TOTAL_STR._LANDED                           48
# B_TOTAL_STR._ATT                              89
# B_TOTAL_STR._LANDED                           40
# R_TD_ATT                                       0
# R_TD_LANDED                                    0
# B_TD_ATT                                       3
# B_TD_LANDED                                    0
# R_HEAD_ATT                                    81
# R_HEAD_LANDED                                 14
# B_HEAD_ATT                                    58
# B_HEAD_LANDED                                 20
# R_BODY_ATT                                    22
# R_BODY_LANDED                                  9
# B_BODY_ATT                                    13
# B_BODY_LANDED                                  7
# R_LEG_ATT                                     29
# R_LEG_LANDED                                  25
# B_LEG_ATT                                     18
# B_LEG_LANDED                                  13
# R_DISTANCE_ATT                               132
# R_DISTANCE_LANDED                             48
# B_DISTANCE_ATT                                82
# B_DISTANCE_LANDED                             35
# R_CLINCH_ATT                                   0
# R_CLINCH_LANDED                                0
# B_CLINCH_ATT                                   7
# B_CLINCH_LANDED                                5
# R_GROUND_ATT                                   0
# R_GROUND_LANDED                                0
# B_GROUND_ATT                                   0
# B_GROUND_LANDED                                0
#
#                                                       1  \
# R_fighter                                   Weili Zhang
# B_fighter                            Joanna Jedrzejczyk
# R_KD                                                  0
# B_KD                                                  0
# R_SIG_STR_pct                                       40%
# B_SIG_STR_pct                                       51%
# R_TD_pct                                            12%
# B_TD_pct                                             0%
# R_SUB_ATT                                             0
# B_SUB_ATT                                             0
# R_PASS                                                0
# B_PASS                                                0
# R_REV                                                 0
# B_REV                                                 0
# win_by                                 Decision - Split
# last_round                                            5
# last_round_time                                    5:00
# Format                                5 Rnd (5-5-5-5-5)
# Referee                                  Keith Peterson
# date                                     March 07, 2020
# location                         Las Vegas, Nevada, USA
# Fight_type           UFC Women's Strawweight Title Bout
# Winner                                      Weili Zhang
# R_SIG_STR._ATT                                      408
# R_SIG_STR._LANDED                                   165
# B_SIG_STR._ATT                                      360
# B_SIG_STR._LANDED                                   186
# R_TOTAL_STR._ATT                                    413
# R_TOTAL_STR._LANDED                                 170
# B_TOTAL_STR._ATT                                    370
# B_TOTAL_STR._LANDED                                 196
# R_TD_ATT                                              8
# R_TD_LANDED                                           1
# B_TD_ATT                                              0
# B_TD_LANDED                                           0
# R_HEAD_ATT                                          305
# R_HEAD_LANDED                                        96
# B_HEAD_ATT                                          230
# B_HEAD_LANDED                                        96
# R_BODY_ATT                                           22
# R_BODY_LANDED                                        11
# B_BODY_ATT                                           47
# B_BODY_LANDED                                        32
# R_LEG_ATT                                            81
# R_LEG_LANDED                                         58
# B_LEG_ATT                                            83
# B_LEG_LANDED                                         58
# R_DISTANCE_ATT                                      393
# R_DISTANCE_LANDED                                   158
# B_DISTANCE_ATT                                      342
# B_DISTANCE_LANDED                                   171
# R_CLINCH_ATT                                         15
# R_CLINCH_LANDED                                       7
# B_CLINCH_ATT                                         18
# B_CLINCH_LANDED                                      15
# R_GROUND_ATT                                          0
# R_GROUND_LANDED                                       0
# B_GROUND_ATT                                          0
# B_GROUND_LANDED                                       0
#
#                                           2                       3  \
# R_fighter                    Beneil Dariush              Neil Magny
# B_fighter                     Drakkar Klose            Jingliang Li
# R_KD                                      1                       0
# B_KD                                      0                       0
# R_SIG_STR_pct                           60%                     53%
# B_SIG_STR_pct                           60%                     25%
# R_TD_pct                                33%                     57%
# B_TD_pct                                 0%                     66%
# R_SUB_ATT                                 2                       0
# B_SUB_ATT                                 0                       0
# R_PASS                                    1                       2
# B_PASS                                    0                       0
# R_REV                                     0                       0
# B_REV                                     0                       0
# win_by                               KO/TKO    Decision - Unanimous
# last_round                                2                       3
# last_round_time                        1:00                    5:00
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                        Jason Herzog          Keith Peterson
# date                         March 07, 2020          March 07, 2020
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                 Lightweight Bout       Welterweight Bout
# Winner                       Beneil Dariush              Neil Magny
# R_SIG_STR._ATT                           20                     139
# R_SIG_STR._LANDED                        12                      74
# B_SIG_STR._ATT                           25                      62
# B_SIG_STR._LANDED                        15                      16
# R_TOTAL_STR._ATT                         28                     188
# R_TOTAL_STR._LANDED                      17                     123
# B_TOTAL_STR._ATT                         37                      65
# B_TOTAL_STR._LANDED                      27                      16
# R_TD_ATT                                  3                       7
# R_TD_LANDED                               1                       4
# B_TD_ATT                                  0                       3
# B_TD_LANDED                               0                       2
# R_HEAD_ATT                               16                     118
# R_HEAD_LANDED                             8                      56
# B_HEAD_ATT                               22                      50
# B_HEAD_LANDED                            12                      11
# R_BODY_ATT                                3                      15
# R_BODY_LANDED                             3                      12
# B_BODY_ATT                                0                       3
# B_BODY_LANDED                             0                       1
# R_LEG_ATT                                 1                       6
# R_LEG_LANDED                              1                       6
# B_LEG_ATT                                 3                       9
# B_LEG_LANDED                              3                       4
# R_DISTANCE_ATT                           20                      96
# R_DISTANCE_LANDED                        12                      34
# B_DISTANCE_ATT                           22                      53
# B_DISTANCE_LANDED                        13                      13
# R_CLINCH_ATT                              0                      20
# R_CLINCH_LANDED                           0                      18
# B_CLINCH_ATT                              3                       9
# B_CLINCH_LANDED                           2                       3
# R_GROUND_ATT                              0                      23
# R_GROUND_LANDED                           0                      22
# B_GROUND_ATT                              0                       0
# B_GROUND_LANDED                           0                       0
#
#                                           4
# R_fighter                     Alex Oliveira
# B_fighter                       Max Griffin
# R_KD                                      0
# B_KD                                      0
# R_SIG_STR_pct                           51%
# B_SIG_STR_pct                           46%
# R_TD_pct                                20%
# B_TD_pct                                66%
# R_SUB_ATT                                 0
# B_SUB_ATT                                 0
# R_PASS                                    2
# B_PASS                                    2
# R_REV                                     0
# B_REV                                     1
# win_by                     Decision - Split
# last_round                                3
# last_round_time                        5:00
# Format                        3 Rnd (5-5-5)
# Referee                          Mark Smith
# date                         March 07, 2020
# location             Las Vegas, Nevada, USA
# Fight_type                Welterweight Bout
# Winner                        Alex Oliveira
# R_SIG_STR._ATT                           77
# R_SIG_STR._LANDED                        40
# B_SIG_STR._ATT                           50
# B_SIG_STR._LANDED                        23
# R_TOTAL_STR._ATT                         98
# R_TOTAL_STR._LANDED                      61
# B_TOTAL_STR._ATT                         96
# B_TOTAL_STR._LANDED                      62
# R_TD_ATT                                  5
# R_TD_LANDED                               1
# B_TD_ATT                                  3
# B_TD_LANDED                               2
# R_HEAD_ATT                               56
# R_HEAD_LANDED                            21
# B_HEAD_ATT                               40
# B_HEAD_LANDED                            17
# R_BODY_ATT                               13
# R_BODY_LANDED                            11
# B_BODY_ATT                                8
# B_BODY_LANDED                             4
# R_LEG_ATT                                 8
# R_LEG_LANDED                              8
# B_LEG_ATT                                 2
# B_LEG_LANDED                              2
# R_DISTANCE_ATT                           67
# R_DISTANCE_LANDED                        35
# B_DISTANCE_ATT                           47
# B_DISTANCE_LANDED                        20
# R_CLINCH_ATT                              8
# R_CLINCH_LANDED                           3
# B_CLINCH_ATT                              3
# B_CLINCH_LANDED                           3
# R_GROUND_ATT                              2
# R_GROUND_LANDED                           2
# B_GROUND_ATT                              0
# B_GROUND_LANDED                           0

# %% [markdown]
# - check for NULL values

# %%
for col in df_fights:
    if df_fights[col].isnull().sum()!=0:
        print(f'Null count in {col} = {df_fights[col].isnull().sum()}')
# Out:
# Null count in Referee = 25
# Null count in Winner = 92

# %%
df_fights[df_fights['Winner'].isnull()]['win_by'].value_counts()
# Out:
# Overturned              37
# Decision - Majority     22
# Could Not Continue      15
# Decision - Split        11
# Decision - Unanimous     5
# Other                    2
# Name: win_by, dtype: int64

# %%
df_fights['Winner'].fillna('Draw', inplace=True)

# %% [markdown]
# - convert percentages to decimal values

# %%
percentage_columns = ['R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

for col in percentage_columns:
    df_fights[col] = df_fights[col].apply(lambda x : float(x.replace('%',''))/100)

# %% [markdown]
# - isolating Title fights and weight classes

# %%
df_fights['Fight_type'].value_counts()[df_fights['Fight_type'].value_counts() > 1].index
# Out:
# Index(['Lightweight Bout', 'Welterweight Bout', 'Middleweight Bout',
#        'Light Heavyweight Bout', 'Heavyweight Bout', 'Featherweight Bout',
#        'Bantamweight Bout', 'Flyweight Bout', 'Women's Strawweight Bout',
#        'Women's Bantamweight Bout', 'Open Weight Bout',
#        'Women's Flyweight Bout', 'UFC Light Heavyweight Title Bout',
#        'UFC Welterweight Title Bout', 'UFC Heavyweight Title Bout',
#        'UFC Middleweight Title Bout', 'UFC Lightweight Title Bout',
#        'Catch Weight Bout', 'UFC Flyweight Title Bout',
#        'UFC Women's Bantamweight Title Bout', 'UFC Featherweight Title Bout',
#        'UFC Bantamweight Title Bout', 'UFC Women's Strawweight Title Bout',
#        'Women's Featherweight Bout', 'UFC Interim Heavyweight Title Bout',
#        'UFC Women's Flyweight Title Bout',
#        'UFC Women's Featherweight Title Bout',
#        'UFC Superfight Championship Bout',
#        'UFC Interim Bantamweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Light Heavyweight Title Bout'],
#       dtype='object')

# %%
df_fights['title_bout'] = df_fights['Fight_type'].apply(lambda x: 1 if 'Title Bout' in x else 0)

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

def make_weight_class(x):
    for weight_class in weight_classes:
        if weight_class in x:
            return weight_class
    if x == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
df_fights['weight_class'] = df_fights['Fight_type'].apply(make_weight_class)

# %%
df_fights['weight_class'].value_counts()
# Out:
# Lightweight              1039
# Welterweight             1023
# Middleweight              762
# Heavyweight               537
# Light Heavyweight         535
# Featherweight             488
# Bantamweight              421
# Flyweight                 204
# Women's Strawweight       164
# Women's Bantamweight      129
# Open Weight                92
# Women's Flyweight          77
# Catch Weight               39
# Women's Featherweight      14
# Name: weight_class, dtype: int64

# %% [markdown]
# - isolate total fight time (seconds)

# %%
df_fights['Format'].value_counts()
# Out:
# 3 Rnd (5-5-5)           4847
# 5 Rnd (5-5-5-5-5)        458
# 1 Rnd + OT (12-3)         79
# No Time Limit             37
# 3 Rnd + OT (5-5-5-5)      22
# 1 Rnd + 2OT (15-3-3)      20
# 1 Rnd (20)                20
# 2 Rnd (5-5)               11
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd (18)                 2
# 1 Rnd + OT (15-3)          2
# 1 Rnd (30)                 1
# 1 Rnd + 2OT (24-3-3)       1
# 1 Rnd + OT (27-3)          1
# 1 Rnd + OT (30-3)          1
# 1 Rnd + OT (31-5)          1
# Name: Format, dtype: int64

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, 
                       '5 Rnd (5-5-5-5-5)': 5*60, 
                       '1 Rnd + OT (12-3)': 12*60,
                       'No Time Limit': 1, 
                       '3 Rnd + OT (5-5-5-5)': 5*60, 
                       '1 Rnd (20)': 1*20,
                       '2 Rnd (5-5)': 5*60, 
                       '1 Rnd (15)': 15*60, 
                       '1 Rnd (10)': 10*60,
                       '1 Rnd (12)':12*60, 
                       '1 Rnd + OT (30-5)': 30*60, 
                       '1 Rnd (18)': 18*60, 
                       '1 Rnd + OT (15-3)': 15*60,
                       '1 Rnd (30)': 30*60, 
                       '1 Rnd + OT (31-5)': 31*5,
                       '1 Rnd + OT (27-3)': 27*60, 
                       '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], 
                         '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# '1 Rnd + 2OT (15-3-3)' and '1 Rnd + 2OT (24-3-3)' is not included because it has 3 uneven timed rounds. 
# We'll have to deal with it separately

# %%
# Converting to seconds
df_fights['last_round_time'] = df_fights['last_round_time'].apply(lambda x: int(x.split(':')[0])*60 + int(x.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df_fights['total_time_fought(sec)'] = df_fights.apply(get_total_time, axis=1)

# %%
def get_num_rounds(x):
    if x == 'No Time Limit':
        return 1
    else:
        return len((x.split('(')[1].replace(')','').split('-')))
    
df_fights['no_of_rounds'] = df_fights['Format'].apply(get_num_rounds)

# %% [markdown]
# <h3>Create master DataFrame by integrating fight/fighter data</h3>

# %% [markdown]
# <h4>Consolidate red/blue corner stats to align them with the correct fighter</h4>

# %%
df_master = df_fights.copy(deep=True)

# %%
df_master.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._ATT', 'R_SIG_STR._LANDED',
#        'B_SIG_STR._ATT', 'B_SIG_STR._LANDED', 'R_TOTAL_STR._ATT',
#        'R_TOTAL_STR._LANDED', 'B_TOTAL_STR._ATT', 'B_TOTAL_STR._LANDED',
#        'R_TD_ATT', 'R_TD_LANDED', 'B_TD_ATT', 'B_TD_LANDED', 'R_HEAD_ATT',
#        'R_HEAD_LANDED', 'B_HEAD_ATT', 'B_HEAD_LANDED', 'R_BODY_ATT',
#        'R_BODY_LANDED', 'B_BODY_ATT', 'B_BODY_LANDED', 'R_LEG_ATT',
#        'R_LEG_LANDED', 'B_LEG_ATT', 'B_LEG_LANDED', 'R_DISTANCE_ATT',
#        'R_DISTANCE_LANDED', 'B_DISTANCE_ATT', 'B_DISTANCE_LANDED',
#        'R_CLINCH_ATT', 'R_CLINCH_LANDED', 'B_CLINCH_ATT', 'B_CLINCH_LANDED',
#        'R_GROUND_ATT', 'R_GROUND_LANDED', 'B_GROUND_ATT', 'B_GROUND_LANDED',
#        'title_bout', 'weight_class', 'total_time_fought(sec)', 'no_of_rounds'],
#       dtype='object')

# %%
df_master.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'win_by', 'last_round',
       'last_round_time', 'Format',
       'Fight_type', 'R_SIG_STR._ATT', 'R_SIG_STR._LANDED',
       'B_SIG_STR._ATT', 'B_SIG_STR._LANDED', 'R_TOTAL_STR._ATT',
       'R_TOTAL_STR._LANDED', 'B_TOTAL_STR._ATT', 'B_TOTAL_STR._LANDED',
       'R_TD_ATT', 'R_TD_LANDED', 'B_TD_ATT', 'B_TD_LANDED', 'R_HEAD_ATT',
       'R_HEAD_LANDED', 'B_HEAD_ATT', 'B_HEAD_LANDED', 'R_BODY_ATT',
       'R_BODY_LANDED', 'B_BODY_ATT', 'B_BODY_LANDED', 'R_LEG_ATT',
       'R_LEG_LANDED', 'B_LEG_ATT', 'B_LEG_LANDED', 'R_DISTANCE_ATT',
       'R_DISTANCE_LANDED', 'B_DISTANCE_ATT', 'B_DISTANCE_LANDED',
       'R_CLINCH_ATT', 'R_CLINCH_LANDED', 'B_CLINCH_ATT', 'B_CLINCH_LANDED',
       'R_GROUND_ATT', 'R_GROUND_LANDED', 'B_GROUND_ATT', 'B_GROUND_LANDED'], axis = 1, inplace=True)

# %%
df_master.head(2)
# Out:
#          R_fighter           B_fighter          Referee            date  \
# 0  Israel Adesanya         Yoel Romero  Dan Miragliotta  March 07, 2020
# 1      Weili Zhang  Joanna Jedrzejczyk   Keith Peterson  March 07, 2020
#
#                  location           Winner  title_bout         weight_class  \
# 0  Las Vegas, Nevada, USA  Israel Adesanya           1         Middleweight
# 1  Las Vegas, Nevada, USA      Weili Zhang           1  Women's Strawweight
#
#    total_time_fought(sec)  no_of_rounds
# 0                    1500             5
# 1                    1500             5

# %%
df_fights.head()
# Out:
#          R_fighter           B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0  Israel Adesanya         Yoel Romero     0     0           0.36
# 1      Weili Zhang  Joanna Jedrzejczyk     0     0           0.40
# 2   Beneil Dariush       Drakkar Klose     1     0           0.60
# 3       Neil Magny        Jingliang Li     0     0           0.53
# 4    Alex Oliveira         Max Griffin     0     0           0.51
#
#    B_SIG_STR_pct  R_TD_pct  B_TD_pct  R_SUB_ATT  B_SUB_ATT  ...  B_CLINCH_ATT  \
# 0           0.44      0.00      0.00          0          0  ...             7
# 1           0.51      0.12      0.00          0          0  ...            18
# 2           0.60      0.33      0.00          2          0  ...             3
# 3           0.25      0.57      0.66          0          0  ...             9
# 4           0.46      0.20      0.66          0          0  ...             3
#
#    B_CLINCH_LANDED  R_GROUND_ATT  R_GROUND_LANDED B_GROUND_ATT  \
# 0                5             0                0            0
# 1               15             0                0            0
# 2                2             0                0            0
# 3                3            23               22            0
# 4                3             2                2            0
#
#    B_GROUND_LANDED  title_bout         weight_class total_time_fought(sec)  \
# 0                0           1         Middleweight                   1500
# 1                0           1  Women's Strawweight                   1500
# 2                0           0          Lightweight                    360
# 3                0           0         Welterweight                    900
# 4                0           0         Welterweight                    900
#
#   no_of_rounds
# 0            5
# 1            5
# 2            3
# 3            3
# 4            3
#
# [5 rows x 63 columns]

# %%
df_red = df_fights[['R_fighter','R_KD', 'R_SIG_STR_pct',
       'R_TD_pct', 'R_SUB_ATT',
       'R_PASS', 'R_REV', 'win_by', 'last_round',
       'last_round_time', 'Format', 'Referee', 'date', 'location',
       'Fight_type', 'Winner', 'R_SIG_STR._ATT', 'R_SIG_STR._LANDED',
       'R_TOTAL_STR._ATT',
       'R_TOTAL_STR._LANDED',
       'R_TD_ATT', 'R_TD_LANDED', 'R_HEAD_ATT',
       'R_HEAD_LANDED', 'R_BODY_ATT',
       'R_BODY_LANDED',  'R_LEG_ATT',
       'R_LEG_LANDED',  'R_DISTANCE_ATT',
       'R_DISTANCE_LANDED', 
       'R_CLINCH_ATT', 'R_CLINCH_LANDED',
       'R_GROUND_ATT', 'R_GROUND_LANDED',
       'title_bout', 'weight_class', 'total_time_fought(sec)', 'no_of_rounds']]

df_blue = df_fights[['B_fighter',  'B_KD',
       'B_SIG_STR_pct','B_TD_pct', 'B_SUB_ATT',
       'B_PASS',  'B_REV', 'win_by', 'last_round',
       'last_round_time', 'Format', 'Referee', 'date', 'location',
       'Fight_type', 'Winner',
       'B_SIG_STR._ATT', 'B_SIG_STR._LANDED',
       'B_TOTAL_STR._ATT', 'B_TOTAL_STR._LANDED',
       'B_TD_ATT', 'B_TD_LANDED',
       'B_HEAD_ATT', 'B_HEAD_LANDED', 
       'B_BODY_ATT', 'B_BODY_LANDED', 
       'B_LEG_ATT', 'B_LEG_LANDED', 
       'B_DISTANCE_ATT', 'B_DISTANCE_LANDED',
       'B_CLINCH_ATT', 'B_CLINCH_LANDED',
       'B_GROUND_ATT', 'B_GROUND_LANDED',
       'title_bout', 'weight_class', 'total_time_fought(sec)', 'no_of_rounds']]

# %% [markdown]
# - get rid of red/blue corner prefixes in order to union fighter history

# %%
def drop_prefix(self, prefix):
    self.columns = self.columns.str.replace('^'+prefix,'')
    return self

pd.core.frame.DataFrame.drop_prefix = drop_prefix

# %%
union = pd.concat([df_red.drop_prefix('R_'), df_blue.drop_prefix('B_')])

# %% [markdown]
# - join this combined fight history DataFrame to the originial fighter DataFrame

# %%
union[union['fighter']=='Daniel Cormier'].T
# Out:
#                                               268   \
# fighter                             Daniel Cormier
# KD                                               0
# SIG_STR_pct                                   0.68
# TD_pct                                        0.33
# SUB_ATT                                          0
# PASS                                             2
# REV                                              0
# win_by                                      KO/TKO
# last_round                                       4
# last_round_time                                249
# Format                           5 Rnd (5-5-5-5-5)
# Referee                                  Herb Dean
# date                               August 17, 2019
# location                  Anaheim, California, USA
# Fight_type              UFC Heavyweight Title Bout
# Winner                                Stipe Miocic
# SIG_STR._ATT                                   263
# SIG_STR._LANDED                                181
# TOTAL_STR._ATT                                 317
# TOTAL_STR._LANDED                              230
# TD_ATT                                           3
# TD_LANDED                                        1
# HEAD_ATT                                       243
# HEAD_LANDED                                    162
# BODY_ATT                                         9
# BODY_LANDED                                      9
# LEG_ATT                                         11
# LEG_LANDED                                      10
# DISTANCE_ATT                                   209
# DISTANCE_LANDED                                139
# CLINCH_ATT                                      27
# CLINCH_LANDED                                   21
# GROUND_ATT                                      27
# GROUND_LANDED                                   21
# title_bout                                       1
# weight_class                           Heavyweight
# total_time_fought(sec)                        1149
# no_of_rounds                                     5
#
#                                                 698   \
# fighter                               Daniel Cormier
# KD                                                 0
# SIG_STR_pct                                     0.76
# TD_pct                                             1
# SUB_ATT                                            1
# PASS                                               4
# REV                                                0
# win_by                                    Submission
# last_round                                         2
# last_round_time                                  134
# Format                             5 Rnd (5-5-5-5-5)
# Referee                                    Herb Dean
# date                               November 03, 2018
# location                New York City, New York, USA
# Fight_type                UFC Heavyweight Title Bout
# Winner                                Daniel Cormier
# SIG_STR._ATT                                      25
# SIG_STR._LANDED                                   19
# TOTAL_STR._ATT                                    54
# TOTAL_STR._LANDED                                 42
# TD_ATT                                             4
# TD_LANDED                                          4
# HEAD_ATT                                          22
# HEAD_LANDED                                       16
# BODY_ATT                                           2
# BODY_LANDED                                        2
# LEG_ATT                                            1
# LEG_LANDED                                         1
# DISTANCE_ATT                                       6
# DISTANCE_LANDED                                    4
# CLINCH_ATT                                         1
# CLINCH_LANDED                                      1
# GROUND_ATT                                        18
# GROUND_LANDED                                     14
# title_bout                                         1
# weight_class                             Heavyweight
# total_time_fought(sec)                           434
# no_of_rounds                                       5
#
#                                                     1052  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.52
# TD_pct                                              0.66
# SUB_ATT                                                1
# PASS                                                   3
# REV                                                    0
# win_by                                            KO/TKO
# last_round                                             2
# last_round_time                                      120
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                  Kevin MacDonald
# date                                    January 20, 2018
# location                      Boston, Massachusetts, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                    Daniel Cormier
# SIG_STR._ATT                                          61
# SIG_STR._LANDED                                       32
# TOTAL_STR._ATT                                       113
# TOTAL_STR._LANDED                                     84
# TD_ATT                                                 3
# TD_LANDED                                              2
# HEAD_ATT                                              59
# HEAD_LANDED                                           30
# BODY_ATT                                               1
# BODY_LANDED                                            1
# LEG_ATT                                                1
# LEG_LANDED                                             1
# DISTANCE_ATT                                          46
# DISTANCE_LANDED                                       24
# CLINCH_ATT                                             8
# CLINCH_LANDED                                          3
# GROUND_ATT                                             7
# GROUND_LANDED                                          5
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                               420
# no_of_rounds                                           5
#
#                                                     1269  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.41
# TD_pct                                                 0
# SUB_ATT                                                0
# PASS                                                   0
# REV                                                    0
# win_by                                        Overturned
# last_round                                             3
# last_round_time                                      181
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                    John McCarthy
# date                                       July 29, 2017
# location                        Anaheim, California, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                              Draw
# SIG_STR._ATT                                         140
# SIG_STR._LANDED                                       58
# TOTAL_STR._ATT                                       142
# TOTAL_STR._LANDED                                     60
# TD_ATT                                                 3
# TD_LANDED                                              0
# HEAD_ATT                                              99
# HEAD_LANDED                                           29
# BODY_ATT                                              16
# BODY_LANDED                                           12
# LEG_ATT                                               25
# LEG_LANDED                                            17
# DISTANCE_ATT                                         123
# DISTANCE_LANDED                                       46
# CLINCH_ATT                                            17
# CLINCH_LANDED                                         12
# GROUND_ATT                                             0
# GROUND_LANDED                                          0
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                               781
# no_of_rounds                                           5
#
#                                                     1426  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.87
# TD_pct                                               0.5
# SUB_ATT                                                1
# PASS                                                   1
# REV                                                    0
# win_by                                        Submission
# last_round                                             2
# last_round_time                                      217
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                    John McCarthy
# date                                      April 08, 2017
# location                          Buffalo, New York, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                    Daniel Cormier
# SIG_STR._ATT                                          41
# SIG_STR._LANDED                                       36
# TOTAL_STR._ATT                                        97
# TOTAL_STR._LANDED                                     85
# TD_ATT                                                 2
# TD_LANDED                                              1
# HEAD_ATT                                              34
# HEAD_LANDED                                           29
# BODY_ATT                                               4
# BODY_LANDED                                            4
# LEG_ATT                                                3
# LEG_LANDED                                             3
# DISTANCE_ATT                                           5
# DISTANCE_LANDED                                        1
# CLINCH_ATT                                            22
# CLINCH_LANDED                                         21
# GROUND_ATT                                            14
# GROUND_LANDED                                         14
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                               517
# no_of_rounds                                           5
#
#                                           1790  \
# fighter                         Daniel Cormier
# KD                                           0
# SIG_STR_pct                               0.51
# TD_pct                                       1
# SUB_ATT                                      0
# PASS                                         3
# REV                                          0
# win_by                    Decision - Unanimous
# last_round                                   3
# last_round_time                            300
# Format                           3 Rnd (5-5-5)
# Referee                          John McCarthy
# date                             July 09, 2016
# location                Las Vegas, Nevada, USA
# Fight_type              Light Heavyweight Bout
# Winner                          Daniel Cormier
# SIG_STR._ATT                                64
# SIG_STR._LANDED                             33
# TOTAL_STR._ATT                             208
# TOTAL_STR._LANDED                          153
# TD_ATT                                       3
# TD_LANDED                                    3
# HEAD_ATT                                    56
# HEAD_LANDED                                 27
# BODY_ATT                                     4
# BODY_LANDED                                  2
# LEG_ATT                                      4
# LEG_LANDED                                   4
# DISTANCE_ATT                                38
# DISTANCE_LANDED                             15
# CLINCH_ATT                                   0
# CLINCH_LANDED                                0
# GROUND_ATT                                  26
# GROUND_LANDED                               18
# title_bout                                   0
# weight_class                 Light Heavyweight
# total_time_fought(sec)                     900
# no_of_rounds                                 3
#
#                                                     2130  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.49
# TD_pct                                               0.2
# SUB_ATT                                                0
# PASS                                                   2
# REV                                                    0
# win_by                                  Decision - Split
# last_round                                             5
# last_round_time                                      300
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                        Herb Dean
# date                                    October 03, 2015
# location                             Houston, Texas, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                    Daniel Cormier
# SIG_STR._ATT                                         283
# SIG_STR._LANDED                                      140
# TOTAL_STR._ATT                                       364
# TOTAL_STR._LANDED                                    219
# TD_ATT                                                 5
# TD_LANDED                                              1
# HEAD_ATT                                             240
# HEAD_LANDED                                          111
# BODY_ATT                                              22
# BODY_LANDED                                           11
# LEG_ATT                                               21
# LEG_LANDED                                            18
# DISTANCE_ATT                                         212
# DISTANCE_LANDED                                       86
# CLINCH_ATT                                            64
# CLINCH_LANDED                                         48
# GROUND_ATT                                             7
# GROUND_LANDED                                          6
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                              1500
# no_of_rounds                                           5
#
#                                           2822                    2932  \
# fighter                         Daniel Cormier          Daniel Cormier
# KD                                           0                       1
# SIG_STR_pct                               0.62                    0.48
# TD_pct                                       1                       0
# SUB_ATT                                      2                       0
# PASS                                        11                       0
# REV                                          0                       0
# win_by                              Submission                  KO/TKO
# last_round                                   3                       1
# last_round_time                            233                      79
# Format                           3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                           Yves Lavigne          Mario Yamasaki
# date                              May 24, 2014       February 22, 2014
# location                Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type              Light Heavyweight Bout  Light Heavyweight Bout
# Winner                          Daniel Cormier          Daniel Cormier
# SIG_STR._ATT                                80                      37
# SIG_STR._LANDED                             50                      18
# TOTAL_STR._ATT                             173                      39
# TOTAL_STR._LANDED                          131                      20
# TD_ATT                                       3                       0
# TD_LANDED                                    3                       0
# HEAD_ATT                                    64                      35
# HEAD_LANDED                                 35                      16
# BODY_ATT                                    16                       2
# BODY_LANDED                                 15                       2
# LEG_ATT                                      0                       0
# LEG_LANDED                                   0                       0
# DISTANCE_ATT                                17                      18
# DISTANCE_LANDED                              4                       4
# CLINCH_ATT                                   0                       6
# CLINCH_LANDED                                0                       5
# GROUND_ATT                                  63                      13
# GROUND_LANDED                               46                       9
# title_bout                                   0                       0
# weight_class                 Light Heavyweight       Light Heavyweight
# total_time_fought(sec)                     833                      79
# no_of_rounds                                 3                       3
#
#                                         3091                        838   \
# fighter                       Daniel Cormier              Daniel Cormier
# KD                                         0                           1
# SIG_STR_pct                              0.5                        0.67
# TD_pct                                   0.6                           0
# SUB_ATT                                    0                           0
# PASS                                       0                           0
# REV                                        0                           0
# win_by                  Decision - Unanimous                      KO/TKO
# last_round                                 3                           1
# last_round_time                          300                         273
# Format                         3 Rnd (5-5-5)           5 Rnd (5-5-5-5-5)
# Referee                       Jacob Montalvo                Marc Goddard
# date                        October 19, 2013               July 07, 2018
# location                 Houston, Texas, USA      Las Vegas, Nevada, USA
# Fight_type                  Heavyweight Bout  UFC Heavyweight Title Bout
# Winner                        Daniel Cormier              Daniel Cormier
# SIG_STR._ATT                             148                          37
# SIG_STR._LANDED                           74                          25
# TOTAL_STR._ATT                           157                          43
# TOTAL_STR._LANDED                         83                          31
# TD_ATT                                     5                           0
# TD_LANDED                                  3                           0
# HEAD_ATT                                 121                          30
# HEAD_LANDED                               50                          20
# BODY_ATT                                  15                           1
# BODY_LANDED                               13                           1
# LEG_ATT                                   12                           6
# LEG_LANDED                                11                           4
# DISTANCE_ATT                             129                          31
# DISTANCE_LANDED                           59                          19
# CLINCH_ATT                                15                           2
# CLINCH_LANDED                             12                           2
# GROUND_ATT                                 4                           4
# GROUND_LANDED                              3                           4
# title_bout                                 0                           1
# weight_class                     Heavyweight                 Heavyweight
# total_time_fought(sec)                   900                         273
# no_of_rounds                               3                           5
#
#                                                     2314  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.56
# TD_pct                                              0.37
# SUB_ATT                                                3
# PASS                                                   4
# REV                                                    0
# win_by                                        Submission
# last_round                                             3
# last_round_time                                      159
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                    John McCarthy
# date                                        May 23, 2015
# location                          Las Vegas, Nevada, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                    Daniel Cormier
# SIG_STR._ATT                                          41
# SIG_STR._LANDED                                       23
# TOTAL_STR._ATT                                        92
# TOTAL_STR._LANDED                                     70
# TD_ATT                                                 8
# TD_LANDED                                              3
# HEAD_ATT                                              37
# HEAD_LANDED                                           20
# BODY_ATT                                               2
# BODY_LANDED                                            2
# LEG_ATT                                                2
# LEG_LANDED                                             1
# DISTANCE_ATT                                          17
# DISTANCE_LANDED                                        5
# CLINCH_ATT                                             4
# CLINCH_LANDED                                          3
# GROUND_ATT                                            20
# GROUND_LANDED                                         15
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                               759
# no_of_rounds                                           5
#
#                                                     2485  \
# fighter                                   Daniel Cormier
# KD                                                     0
# SIG_STR_pct                                         0.35
# TD_pct                                              0.12
# SUB_ATT                                                0
# PASS                                                   0
# REV                                                    0
# win_by                              Decision - Unanimous
# last_round                                             5
# last_round_time                                      300
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                        Herb Dean
# date                                    January 03, 2015
# location                          Las Vegas, Nevada, USA
# Fight_type              UFC Light Heavyweight Title Bout
# Winner                                         Jon Jones
# SIG_STR._ATT                                         165
# SIG_STR._LANDED                                       58
# TOTAL_STR._ATT                                       191
# TOTAL_STR._LANDED                                     78
# TD_ATT                                                 8
# TD_LANDED                                              1
# HEAD_ATT                                             130
# HEAD_LANDED                                           40
# BODY_ATT                                              19
# BODY_LANDED                                           11
# LEG_ATT                                               16
# LEG_LANDED                                             7
# DISTANCE_ATT                                         121
# DISTANCE_LANDED                                       35
# CLINCH_ATT                                            42
# CLINCH_LANDED                                         22
# GROUND_ATT                                             2
# GROUND_LANDED                                          1
# title_bout                                             1
# weight_class                           Light Heavyweight
# total_time_fought(sec)                              1500
# no_of_rounds                                           5
#
#                                              3269
# fighter                            Daniel Cormier
# KD                                              0
# SIG_STR_pct                                  0.61
# TD_pct                                          0
# SUB_ATT                                         0
# PASS                                            0
# REV                                             0
# win_by                       Decision - Unanimous
# last_round                                      3
# last_round_time                               300
# Format                              3 Rnd (5-5-5)
# Referee                                 Herb Dean
# date                               April 20, 2013
# location                San Jose, California, USA
# Fight_type                       Heavyweight Bout
# Winner                             Daniel Cormier
# SIG_STR._ATT                                   96
# SIG_STR._LANDED                                59
# TOTAL_STR._ATT                                139
# TOTAL_STR._LANDED                             102
# TD_ATT                                          1
# TD_LANDED                                       0
# HEAD_ATT                                       57
# HEAD_LANDED                                    27
# BODY_ATT                                       30
# BODY_LANDED                                    23
# LEG_ATT                                         9
# LEG_LANDED                                      9
# DISTANCE_ATT                                   32
# DISTANCE_LANDED                                10
# CLINCH_ATT                                     64
# CLINCH_LANDED                                  49
# GROUND_ATT                                      0
# GROUND_LANDED                                   0
# title_bout                                      0
# weight_class                          Heavyweight
# total_time_fought(sec)                        900
# no_of_rounds                                    3

# %%
df_fighter_history = pd.merge(df_fighters, union, left_on='fighter_name', right_on='fighter', how='left', indicator=True)

# %% [markdown]
# - 1,330 fighters without any fight stats (in original fighter dataset)
#     - However, every fighter involved in a historical bout is contained in the original fighter dataset

# %%
union.shape
# Out:
# (11048, 38)

# %%
df_fighter_history.shape
# Out:
# (12370, 45)

# %%
df_fighter_history._merge.value_counts()
# Out:
# both          11040
# left_only      1330
# right_only        0
# Name: _merge, dtype: int64

# %% [markdown]
# - lack of depth in individual fight history presents a problem for forecasting fighter performance

# %%
df_fighter_history['fighter_name'].value_counts()
# Out:
# Donald Cerrone      34
# Jim Miller          34
# Jeremy Stephens     32
# Andrei Arlovski     31
# Diego Sanchez       31
#                     ..
# Ricardo Palacios     1
# Matt Horning         1
# Kelly Dullanty       1
# Phil Cardella        1
# Alex Gorgees         1
# Name: fighter_name, Length: 3334, dtype: int64

# %% [markdown]
# <h3>Feature Engineering</h3>

# %%
df_fighter_history.T
# Out:
#                                0                         1      \
# fighter_name               Tom Aaron              Danny Abbadi
# Height                       69.5797                        71
# Weight                           155                       155
# Reach                             70                   72.6813
# Stance                           NaN                  Orthodox
# DOB                     Jul 13, 1978              Jul 03, 1983
# fighter                          NaN              Danny Abbadi
# KD                               NaN                         0
# SIG_STR_pct                      NaN                      0.38
# TD_pct                           NaN                         0
# SUB_ATT                          NaN                         0
# PASS                             NaN                         0
# REV                              NaN                         0
# win_by                           NaN          Decision - Split
# last_round                       NaN                         3
# last_round_time                  NaN                       300
# Format                           NaN             3 Rnd (5-5-5)
# Referee                          NaN                 Herb Dean
# date                             NaN        September 23, 2006
# location                         NaN  Anaheim, California, USA
# Fight_type                       NaN          Lightweight Bout
# Winner                           NaN              Jorge Gurgel
# SIG_STR._ATT                     NaN                       146
# SIG_STR._LANDED                  NaN                        56
# TOTAL_STR._ATT                   NaN                       173
# TOTAL_STR._LANDED                NaN                        79
# TD_ATT                           NaN                         0
# TD_LANDED                        NaN                         0
# HEAD_ATT                         NaN                       137
# HEAD_LANDED                      NaN                        49
# BODY_ATT                         NaN                         9
# BODY_LANDED                      NaN                         7
# LEG_ATT                          NaN                         0
# LEG_LANDED                       NaN                         0
# DISTANCE_ATT                     NaN                       122
# DISTANCE_LANDED                  NaN                        41
# CLINCH_ATT                       NaN                        20
# CLINCH_LANDED                    NaN                        12
# GROUND_ATT                       NaN                         4
# GROUND_LANDED                    NaN                         3
# title_bout                       NaN                         0
# weight_class                     NaN               Lightweight
# total_time_fought(sec)           NaN                       900
# no_of_rounds                     NaN                         3
# _merge                     left_only                      both
#
#                                          2                     3      \
# fighter_name                      Danny Abbadi          David Abbott
# Height                                      71                    72
# Weight                                     155                   265
# Reach                                  72.6813                 73.75
# Stance                                Orthodox                Switch
# DOB                               Jul 03, 1983                   NaN
# fighter                           Danny Abbadi          David Abbott
# KD                                           0                     0
# SIG_STR_pct                               0.33                  0.68
# TD_pct                                       0                     0
# SUB_ATT                                      0                     0
# PASS                                         0                     0
# REV                                          0                     1
# win_by                              Submission                KO/TKO
# last_round                                   1                     1
# last_round_time                            176                    43
# Format                           3 Rnd (5-5-5)     1 Rnd + OT (12-3)
# Referee                         Mario Yamasaki         John McCarthy
# date                             June 24, 2006          May 15, 1998
# location                Las Vegas, Nevada, USA  Mobile, Alabama, USA
# Fight_type                   Middleweight Bout      Heavyweight Bout
# Winner                           Kalib Starnes          David Abbott
# SIG_STR._ATT                                 9                    16
# SIG_STR._LANDED                              3                    11
# TOTAL_STR._ATT                              12                    16
# TOTAL_STR._LANDED                            6                    11
# TD_ATT                                       0                     0
# TD_LANDED                                    0                     0
# HEAD_ATT                                     8                    16
# HEAD_LANDED                                  2                    11
# BODY_ATT                                     1                     0
# BODY_LANDED                                  1                     0
# LEG_ATT                                      0                     0
# LEG_LANDED                                   0                     0
# DISTANCE_ATT                                 5                     0
# DISTANCE_LANDED                              1                     0
# CLINCH_ATT                                   4                     3
# CLINCH_LANDED                                2                     2
# GROUND_ATT                                   0                    13
# GROUND_LANDED                                0                     9
# title_bout                                   0                     0
# weight_class                      Middleweight           Heavyweight
# total_time_fought(sec)                     176                    43
# no_of_rounds                                 3                     2
# _merge                                    both                  both
#
#                                             4                         5      \
# fighter_name                         David Abbott              David Abbott
# Height                                         72                        72
# Weight                                        265                       265
# Reach                                       73.75                     73.75
# Stance                                     Switch                    Switch
# DOB                                           NaN                       NaN
# fighter                              David Abbott              David Abbott
# KD                                              0                         1
# SIG_STR_pct                                  0.41                      0.52
# TD_pct                                       0.75                         1
# SUB_ATT                                         0                         0
# PASS                                            1                         1
# REV                                             0                         0
# win_by                       Decision - Unanimous                    KO/TKO
# last_round                                      2                         1
# last_round_time                               180                        63
# Format                          1 Rnd + OT (12-3)         1 Rnd + OT (12-3)
# Referee                             John McCarthy             John McCarthy
# date                            December 21, 1997         December 07, 1996
# location                Yokohama, Kanagawa, Japan  Birmingham, Alabama, USA
# Fight_type                       Heavyweight Bout          Open Weight Bout
# Winner                               David Abbott              David Abbott
# SIG_STR._ATT                                   31                        17
# SIG_STR._LANDED                                13                         9
# TOTAL_STR._ATT                                 90                        21
# TOTAL_STR._LANDED                              69                        13
# TD_ATT                                          4                         1
# TD_LANDED                                       3                         1
# HEAD_ATT                                       31                        17
# HEAD_LANDED                                    13                         9
# BODY_ATT                                        0                         0
# BODY_LANDED                                     0                         0
# LEG_ATT                                         0                         0
# LEG_LANDED                                      0                         0
# DISTANCE_ATT                                   12                         1
# DISTANCE_LANDED                                 6                         1
# CLINCH_ATT                                      0                        16
# CLINCH_LANDED                                   0                         8
# GROUND_ATT                                     19                         0
# GROUND_LANDED                                   7                         0
# title_bout                                      0                         0
# weight_class                          Heavyweight               Open Weight
# total_time_fought(sec)                        900                        63
# no_of_rounds                                    2                         2
# _merge                                       both                      both
#
#                                            6                      7      \
# fighter_name                        David Abbott           David Abbott
# Height                                        72                     72
# Weight                                       265                    265
# Reach                                      73.75                  73.75
# Stance                                    Switch                 Switch
# DOB                                          NaN                    NaN
# fighter                             David Abbott           David Abbott
# KD                                             0                      0
# SIG_STR_pct                                 0.44                   0.88
# TD_pct                                         0                      1
# SUB_ATT                                        1                      1
# PASS                                           1                      1
# REV                                            0                      0
# win_by                                    KO/TKO             Submission
# last_round                                     1                      1
# last_round_time                              171                    126
# Format                         1 Rnd + OT (12-3)             1 Rnd (15)
# Referee                            John McCarthy          John McCarthy
# date                           December 07, 1996     September 20, 1996
# location                Birmingham, Alabama, USA  Augusta, Georgia, USA
# Fight_type                      Open Weight Bout       Open Weight Bout
# Winner                              David Abbott           David Abbott
# SIG_STR._ATT                                   9                      9
# SIG_STR._LANDED                                4                      8
# TOTAL_STR._ATT                                17                     17
# TOTAL_STR._LANDED                              9                     16
# TD_ATT                                         1                      1
# TD_LANDED                                      0                      1
# HEAD_ATT                                       9                      6
# HEAD_LANDED                                    4                      5
# BODY_ATT                                       0                      3
# BODY_LANDED                                    0                      3
# LEG_ATT                                        0                      0
# LEG_LANDED                                     0                      0
# DISTANCE_ATT                                   5                      0
# DISTANCE_LANDED                                1                      0
# CLINCH_ATT                                     0                      0
# CLINCH_LANDED                                  0                      0
# GROUND_ATT                                     4                      9
# GROUND_LANDED                                  3                      8
# title_bout                                     0                      0
# weight_class                         Open Weight            Open Weight
# total_time_fought(sec)                       171                    126
# no_of_rounds                                   2                      1
# _merge                                      both                   both
#
#                                         8                     9      ...  \
# fighter_name                     David Abbott          David Abbott  ...
# Height                                     72                    72  ...
# Weight                                    265                   265  ...
# Reach                                   73.75                 73.75  ...
# Stance                                 Switch                Switch  ...
# DOB                                       NaN                   NaN  ...
# fighter                          David Abbott          David Abbott  ...
# KD                                          0                     0  ...
# SIG_STR_pct                                 1                  0.66  ...
# TD_pct                                      1                     1  ...
# SUB_ATT                                     1                     0  ...
# PASS                                        1                     1  ...
# REV                                         0                     0  ...
# win_by                             Submission                KO/TKO  ...
# last_round                                  1                     1  ...
# last_round_time                            74                   113  ...
# Format                             1 Rnd (15)            1 Rnd (20)  ...
# Referee                         John McCarthy         John McCarthy  ...
# date                        December 16, 1995         July 14, 1995  ...
# location                Denver, Colorado, USA  Casper, Wyoming, USA  ...
# Fight_type                   Open Weight Bout      Open Weight Bout  ...
# Winner                           David Abbott          David Abbott  ...
# SIG_STR._ATT                                1                    21  ...
# SIG_STR._LANDED                             1                    14  ...
# TOTAL_STR._ATT                              5                    25  ...
# TOTAL_STR._LANDED                           3                    18  ...
# TD_ATT                                      1                     1  ...
# TD_LANDED                                   1                     1  ...
# HEAD_ATT                                    1                    20  ...
# HEAD_LANDED                                 1                    13  ...
# BODY_ATT                                    0                     1  ...
# BODY_LANDED                                 0                     1  ...
# LEG_ATT                                     0                     0  ...
# LEG_LANDED                                  0                     0  ...
# DISTANCE_ATT                                1                     1  ...
# DISTANCE_LANDED                             1                     1  ...
# CLINCH_ATT                                  0                     0  ...
# CLINCH_LANDED                               0                     0  ...
# GROUND_ATT                                  0                    20  ...
# GROUND_LANDED                               0                    13  ...
# title_bout                                  0                     0  ...
# weight_class                      Open Weight           Open Weight  ...
# total_time_fought(sec)                     74                   113  ...
# no_of_rounds                                1                     1  ...
# _merge                                   both                  both  ...
#
#                                             12360                      12361  \
# fighter_name                          Cat Zingano                Cat Zingano
# Height                                         66                         66
# Weight                                        145                        145
# Reach                                          68                         68
# Stance                                   Southpaw                   Southpaw
# DOB                                  Jul 01, 1982               Jul 01, 1982
# fighter                               Cat Zingano                Cat Zingano
# KD                                              0                          0
# SIG_STR_pct                                  0.47                       0.66
# TD_pct                                       0.75                          1
# SUB_ATT                                         0                          3
# PASS                                            2                          5
# REV                                             2                          0
# win_by                       Decision - Unanimous                     KO/TKO
# last_round                                      3                          3
# last_round_time                               300                         81
# Format                              3 Rnd (5-5-5)              3 Rnd (5-5-5)
# Referee                                 Herb Dean               Jason Herzog
# date                                July 09, 2016         September 27, 2014
# location                   Las Vegas, Nevada, USA     Las Vegas, Nevada, USA
# Fight_type              Women's Bantamweight Bout  Women's Bantamweight Bout
# Winner                              Julianna Pena                Cat Zingano
# SIG_STR._ATT                                   23                         60
# SIG_STR._LANDED                                11                         40
# TOTAL_STR._ATT                                 37                        116
# TOTAL_STR._LANDED                              23                         93
# TD_ATT                                          4                          3
# TD_LANDED                                       3                          3
# HEAD_ATT                                       18                         49
# HEAD_LANDED                                     6                         31
# BODY_ATT                                        4                          9
# BODY_LANDED                                     4                          7
# LEG_ATT                                         1                          2
# LEG_LANDED                                      1                          2
# DISTANCE_ATT                                   12                          5
# DISTANCE_LANDED                                 3                          1
# CLINCH_ATT                                      3                          8
# CLINCH_LANDED                                   2                          7
# GROUND_ATT                                      8                         47
# GROUND_LANDED                                   6                         32
# title_bout                                      0                          0
# weight_class                 Women's Bantamweight       Women's Bantamweight
# total_time_fought(sec)                        900                        681
# no_of_rounds                                    3                          3
# _merge                                       both                       both
#
#                                                       12362  \
# fighter_name                                    Cat Zingano
# Height                                                   66
# Weight                                                  145
# Reach                                                    68
# Stance                                             Southpaw
# DOB                                            Jul 01, 1982
# fighter                                         Cat Zingano
# KD                                                        0
# SIG_STR_pct                                               0
# TD_pct                                                    0
# SUB_ATT                                                   0
# PASS                                                      0
# REV                                                       0
# win_by                                           Submission
# last_round                                                1
# last_round_time                                          14
# Format                                    5 Rnd (5-5-5-5-5)
# Referee                                       John McCarthy
# date                                      February 28, 2015
# location                       Los Angeles, California, USA
# Fight_type              UFC Women's Bantamweight Title Bout
# Winner                                         Ronda Rousey
# SIG_STR._ATT                                              1
# SIG_STR._LANDED                                           0
# TOTAL_STR._ATT                                            1
# TOTAL_STR._LANDED                                         0
# TD_ATT                                                    0
# TD_LANDED                                                 0
# HEAD_ATT                                                  0
# HEAD_LANDED                                               0
# BODY_ATT                                                  1
# BODY_LANDED                                               0
# LEG_ATT                                                   0
# LEG_LANDED                                                0
# DISTANCE_ATT                                              1
# DISTANCE_LANDED                                           0
# CLINCH_ATT                                                0
# CLINCH_LANDED                                             0
# GROUND_ATT                                                0
# GROUND_LANDED                                             0
# title_bout                                                1
# weight_class                           Women's Bantamweight
# total_time_fought(sec)                                   14
# no_of_rounds                                              5
# _merge                                                 both
#
#                                             12363  \
# fighter_name                          Cat Zingano
# Height                                         66
# Weight                                        145
# Reach                                          68
# Stance                                   Southpaw
# DOB                                  Jul 01, 1982
# fighter                               Cat Zingano
# KD                                              0
# SIG_STR_pct                                  0.83
# TD_pct                                          1
# SUB_ATT                                         1
# PASS                                            4
# REV                                             2
# win_by                                     KO/TKO
# last_round                                      3
# last_round_time                               175
# Format                              3 Rnd (5-5-5)
# Referee                               Kim Winslow
# date                               April 13, 2013
# location                   Las Vegas, Nevada, USA
# Fight_type              Women's Bantamweight Bout
# Winner                                Cat Zingano
# SIG_STR._ATT                                   42
# SIG_STR._LANDED                                35
# TOTAL_STR._ATT                                120
# TOTAL_STR._LANDED                             107
# TD_ATT                                          1
# TD_LANDED                                       1
# HEAD_ATT                                       30
# HEAD_LANDED                                    23
# BODY_ATT                                        8
# BODY_LANDED                                     8
# LEG_ATT                                         4
# LEG_LANDED                                      4
# DISTANCE_ATT                                   22
# DISTANCE_LANDED                                16
# CLINCH_ATT                                      9
# CLINCH_LANDED                                   8
# GROUND_ATT                                     11
# GROUND_LANDED                                  11
# title_bout                                      0
# weight_class                 Women's Bantamweight
# total_time_fought(sec)                        775
# no_of_rounds                                    3
# _merge                                       both
#
#                                                    12364          12365  \
# fighter_name                               Igor Zinoviev  Dave Zitanick
# Height                                                73        71.0858
# Weight                                               199            170
# Reach                                            74.7083         72.018
# Stance                                          Orthodox            NaN
# DOB                                                  NaN   Mar 05, 1980
# fighter                                    Igor Zinoviev            NaN
# KD                                                     0            NaN
# SIG_STR_pct                                            0            NaN
# TD_pct                                                 0            NaN
# SUB_ATT                                                0            NaN
# PASS                                                   0            NaN
# REV                                                    0            NaN
# win_by                                            KO/TKO            NaN
# last_round                                             1            NaN
# last_round_time                                       22            NaN
# Format                              1 Rnd + 2OT (15-3-3)            NaN
# Referee                                    John McCarthy            NaN
# date                                      March 13, 1998            NaN
# location                     New Orleans, Louisiana, USA            NaN
# Fight_type              UFC Light Heavyweight Title Bout            NaN
# Winner                                    Frank Shamrock            NaN
# SIG_STR._ATT                                           2            NaN
# SIG_STR._LANDED                                        0            NaN
# TOTAL_STR._ATT                                         2            NaN
# TOTAL_STR._LANDED                                      0            NaN
# TD_ATT                                                 0            NaN
# TD_LANDED                                              0            NaN
# HEAD_ATT                                               2            NaN
# HEAD_LANDED                                            0            NaN
# BODY_ATT                                               0            NaN
# BODY_LANDED                                            0            NaN
# LEG_ATT                                                0            NaN
# LEG_LANDED                                             0            NaN
# DISTANCE_ATT                                           2            NaN
# DISTANCE_LANDED                                        0            NaN
# CLINCH_ATT                                             0            NaN
# CLINCH_LANDED                                          0            NaN
# GROUND_ATT                                             0            NaN
# GROUND_LANDED                                          0            NaN
# title_bout                                             1            NaN
# weight_class                           Light Heavyweight            NaN
# total_time_fought(sec)                                22            NaN
# no_of_rounds                                           3            NaN
# _merge                                              both      left_only
#
#                               12366          12367                   12368  \
# fighter_name            Alex Zuniga  George Zuniga            Allan Zuniga
# Height                      68.4629             69                      67
# Weight                          145            185                     155
# Reach                        72.018        70.8698                      70
# Stance                          NaN            NaN                Orthodox
# DOB                             NaN            NaN            Apr 04, 1992
# fighter                         NaN            NaN            Allan Zuniga
# KD                              NaN            NaN                       0
# SIG_STR_pct                     NaN            NaN                    0.52
# TD_pct                          NaN            NaN                       0
# SUB_ATT                         NaN            NaN                       1
# PASS                            NaN            NaN                       0
# REV                             NaN            NaN                       0
# win_by                          NaN            NaN     Decision - Majority
# last_round                      NaN            NaN                       3
# last_round_time                 NaN            NaN                     300
# Format                          NaN            NaN           3 Rnd (5-5-5)
# Referee                         NaN            NaN           Chris Tognoni
# date                            NaN            NaN           July 06, 2018
# location                        NaN            NaN  Las Vegas, Nevada, USA
# Fight_type                      NaN            NaN        Lightweight Bout
# Winner                          NaN            NaN            John Gunther
# SIG_STR._ATT                    NaN            NaN                     112
# SIG_STR._LANDED                 NaN            NaN                      59
# TOTAL_STR._ATT                  NaN            NaN                     147
# TOTAL_STR._LANDED               NaN            NaN                      93
# TD_ATT                          NaN            NaN                       0
# TD_LANDED                       NaN            NaN                       0
# HEAD_ATT                        NaN            NaN                      78
# HEAD_LANDED                     NaN            NaN                      33
# BODY_ATT                        NaN            NaN                      24
# BODY_LANDED                     NaN            NaN                      18
# LEG_ATT                         NaN            NaN                      10
# LEG_LANDED                      NaN            NaN                       8
# DISTANCE_ATT                    NaN            NaN                      96
# DISTANCE_LANDED                 NaN            NaN                      44
# CLINCH_ATT                      NaN            NaN                      15
# CLINCH_LANDED                   NaN            NaN                      14
# GROUND_ATT                      NaN            NaN                       1
# GROUND_LANDED                   NaN            NaN                       1
# title_bout                      NaN            NaN                       0
# weight_class                    NaN            NaN             Lightweight
# total_time_fought(sec)          NaN            NaN                     900
# no_of_rounds                    NaN            NaN                       3
# _merge                    left_only      left_only                    both
#
#                                  12369
# fighter_name            Virgil Zwicker
# Height                              74
# Weight                             205
# Reach                               74
# Stance                             NaN
# DOB                       Jun 26, 1982
# fighter                            NaN
# KD                                 NaN
# SIG_STR_pct                        NaN
# TD_pct                             NaN
# SUB_ATT                            NaN
# PASS                               NaN
# REV                                NaN
# win_by                             NaN
# last_round                         NaN
# last_round_time                    NaN
# Format                             NaN
# Referee                            NaN
# date                               NaN
# location                           NaN
# Fight_type                         NaN
# Winner                             NaN
# SIG_STR._ATT                       NaN
# SIG_STR._LANDED                    NaN
# TOTAL_STR._ATT                     NaN
# TOTAL_STR._LANDED                  NaN
# TD_ATT                             NaN
# TD_LANDED                          NaN
# HEAD_ATT                           NaN
# HEAD_LANDED                        NaN
# BODY_ATT                           NaN
# BODY_LANDED                        NaN
# LEG_ATT                            NaN
# LEG_LANDED                         NaN
# DISTANCE_ATT                       NaN
# DISTANCE_LANDED                    NaN
# CLINCH_ATT                         NaN
# CLINCH_LANDED                      NaN
# GROUND_ATT                         NaN
# GROUND_LANDED                      NaN
# title_bout                         NaN
# weight_class                       NaN
# total_time_fought(sec)             NaN
# no_of_rounds                       NaN
# _merge                       left_only
#
# [45 rows x 12370 columns]

# %%
df_fighter_history.drop(columns = ['fighter','Format','Referee','Fight_type'], inplace=True)

# %% [markdown]
# - there are too many distinct locations
#     - in order to create a more signifcant feature, location is adapted to a binary indicator of whether or not the fight took place in Las Vegas, Nevada (i.e. the most popular fight location)

# %%
df_fighter_history['location'].value_counts()
# Out:
# 0    8512
# 1    3858
# Name: location, dtype: int64

# %%
df_fighter_history['location']=df_fighter_history['location'].apply(lambda x: 1 if x.find('Las Vegas')!=-1 else 0)

# %% [markdown]
# - can see that NaN values in fight stats columns are resulting from the left merge
#     - need to populate these values (e.g. averages)
#     - this will not detract from overall data quality because these fighters will not be included in the training data (i.e. real historical bouts)

# %%
df_fighter_history.isna().sum()
# Out:
# fighter_name              0
# Height                    0
# Weight                    0
# Reach                     0
# Stance                    0
# DOB                       0
# KD                        0
# SIG_STR_pct               0
# TD_pct                    0
# SUB_ATT                   0
# PASS                      0
# REV                       0
# win_by                    0
# last_round                0
# last_round_time           0
# date                      0
# location                  0
# SIG_STR._ATT              0
# SIG_STR._LANDED           0
# TOTAL_STR._ATT            0
# TOTAL_STR._LANDED         0
# TD_ATT                    0
# TD_LANDED                 0
# HEAD_ATT                  0
# HEAD_LANDED               0
# BODY_ATT                  0
# BODY_LANDED               0
# LEG_ATT                   0
# LEG_LANDED                0
# DISTANCE_ATT              0
# DISTANCE_LANDED           0
# CLINCH_ATT                0
# CLINCH_LANDED             0
# GROUND_ATT                0
# GROUND_LANDED             0
# title_bout                0
# weight_class              0
# total_time_fought(sec)    0
# no_of_rounds              0
# _merge                    0
# won                       0
# dtype: int64

# %% [markdown]
# - recode winner column to binary

# %%
df_fighter_history['won'] = df_fighter_history.apply(lambda row: 1 if row['Winner'] == row['fighter_name'] else 0, axis=1)

df_fighter_history.drop(columns = ['Winner'], inplace=True)

# %% [markdown]
# - change Date of Birth and fight date from string to datetime

# %%
from datetime import datetime

month_code = {'Jan ': 'January ', 
      'Feb ': 'February ', 
      'Mar ': 'March ', 
      'Apr ': 'April ', 
      'May ': 'May ', 
      'Jun ': 'June ', 
      'Jul ': 'July ', 
      'Aug ': 'August ', 
      'Sep ': 'September ', 
      'Oct ': 'October ', 
      'Nov ': 'November ', 
      'Dec ': 'December '}

for k, v in month_code.items():
    df_fighter_history['DOB'] = df_fighter_history['DOB'].apply(lambda x: x.replace(k, v) if type(x) == str else x)

df_fighter_history['DOB'] = df_fighter_history['DOB'].apply(lambda row: datetime.strptime(row, '%B %d, %Y') if type(row) == str else row)
df_fighter_history['date'] = df_fighter_history['date'].apply(lambda row: datetime.strptime(row, '%B %d, %Y') if type(row) == str else row)

# %% [markdown]
# - define feature groups by broad data type

# %%
num_features = ['KD', 'SIG_STR_pct', 'TD_pct', 'SUB_ATT', 'PASS', 'REV',
       'last_round', 'last_round_time','SIG_STR._ATT',
       'SIG_STR._LANDED', 'TOTAL_STR._ATT', 'TOTAL_STR._LANDED', 'TD_ATT',
       'TD_LANDED', 'HEAD_ATT', 'HEAD_LANDED', 'BODY_ATT', 'BODY_LANDED',
       'LEG_ATT', 'LEG_LANDED', 'DISTANCE_ATT', 'DISTANCE_LANDED',
       'CLINCH_ATT', 'CLINCH_LANDED', 'GROUND_ATT', 'GROUND_LANDED',
       'total_time_fought(sec)', 'no_of_rounds']

categorical_features = ['Stance','win_by',
       'last_round', 'last_round_time', 'location',
       'title_bout', 'weight_class']

date_features = ['DOB','date']

# %% [markdown]
# - replacing NaN values:
#     - numerical: column mean
#     - categorica: column mode
#     - date: column mean

# %%
df_fighter_history.fillna(df_fighter_history.mean(), inplace=True)
df_fighter_history.fillna(df.mode().iloc[0], inplace=True)
df_fighter_history = df_fighter_history.apply(lambda x:x.fillna(x.value_counts().index[0]))
df_fighter_history['date'] = df_fighter_history['date'].apply(lambda row: datetime.strptime(row, '%B %d, %Y') if type(row) == str else row)

# %% [markdown]
# - creating age (at fight date) feature

# %%
df_fighter_history['age'] = df_fighter_history['date'] - df_fighter_history['DOB']
df_fighter_history['age']=df_fighter_history['age']/np.timedelta64(1,'Y')
df_fighter_history['age']=df_fighter_history['age'].apply(lambda x: 25 if x <=18 else x)

# %%
df_fighter_history.isna().sum()
# Out:
# fighter_name              0
# Height                    0
# Weight                    0
# Reach                     0
# Stance                    0
# DOB                       0
# KD                        0
# SIG_STR_pct               0
# TD_pct                    0
# SUB_ATT                   0
# PASS                      0
# REV                       0
# win_by                    0
# last_round                0
# last_round_time           0
# date                      0
# location                  0
# SIG_STR._ATT              0
# SIG_STR._LANDED           0
# TOTAL_STR._ATT            0
# TOTAL_STR._LANDED         0
# TD_ATT                    0
# TD_LANDED                 0
# HEAD_ATT                  0
# HEAD_LANDED               0
# BODY_ATT                  0
# BODY_LANDED               0
# LEG_ATT                   0
# LEG_LANDED                0
# DISTANCE_ATT              0
# DISTANCE_LANDED           0
# CLINCH_ATT                0
# CLINCH_LANDED             0
# GROUND_ATT                0
# GROUND_LANDED             0
# title_bout                0
# weight_class              0
# total_time_fought(sec)    0
# no_of_rounds              0
# _merge                    0
# won                       0
# age                       0
# dtype: int64

# %%
df_fighter_history.drop(columns='_merge', inplace=True)

# %%
df_fighter_history.T
# Out:
#                                          0                         1      \
# fighter_name                         Tom Aaron              Danny Abbadi
# Height                                 69.5797                        71
# Weight                                     155                       155
# Reach                                       70                   72.6813
# Stance                                Orthodox                  Orthodox
# DOB                        1978-07-13 00:00:00       1983-07-03 00:00:00
# KD                                    0.215127                         0
# SIG_STR_pct                           0.440723                      0.38
# TD_pct                                0.275527                         0
# SUB_ATT                               0.422011                         0
# PASS                                   1.10154                         0
# REV                                   0.137319                         0
# win_by                    Decision - Unanimous          Decision - Split
# last_round                             2.30308                         3
# last_round_time                        226.129                       300
# date                       2016-11-19 00:00:00       2006-09-23 00:00:00
# location                Las Vegas, Nevada, USA  Anaheim, California, USA
# SIG_STR._ATT                           75.7565                       146
# SIG_STR._LANDED                        32.4959                        56
# TOTAL_STR._ATT                         96.0553                       173
# TOTAL_STR._LANDED                      50.5371                        79
# TD_ATT                                 2.80362                         0
# TD_LANDED                              1.07092                         0
# HEAD_ATT                               59.4518                       137
# HEAD_LANDED                            20.6553                        49
# BODY_ATT                                9.5702                         9
# BODY_LANDED                            6.51576                         7
# LEG_ATT                                6.73451                         0
# LEG_LANDED                             5.32482                         0
# DISTANCE_ATT                           60.4344                       122
# DISTANCE_LANDED                        22.1208                        41
# CLINCH_ATT                             7.67971                        20
# CLINCH_LANDED                           5.2106                        12
# GROUND_ATT                             7.64239                         4
# GROUND_LANDED                          5.16449                         3
# title_bout                            0.063587                         0
# weight_class                       Lightweight               Lightweight
# total_time_fought(sec)                 619.592                       900
# no_of_rounds                             3.125                         3
# won                                          0                         0
# age                                    38.3553                   23.2257
#
#                                          2                     3      \
# fighter_name                      Danny Abbadi          David Abbott
# Height                                      71                    72
# Weight                                     155                   265
# Reach                                  72.6813                 73.75
# Stance                                Orthodox                Switch
# DOB                        1983-07-03 00:00:00   1984-09-26 00:00:00
# KD                                           0                     0
# SIG_STR_pct                               0.33                  0.68
# TD_pct                                       0                     0
# SUB_ATT                                      0                     0
# PASS                                         0                     0
# REV                                          0                     1
# win_by                              Submission                KO/TKO
# last_round                                   1                     1
# last_round_time                            176                    43
# date                       2006-06-24 00:00:00   1998-05-15 00:00:00
# location                Las Vegas, Nevada, USA  Mobile, Alabama, USA
# SIG_STR._ATT                                 9                    16
# SIG_STR._LANDED                              3                    11
# TOTAL_STR._ATT                              12                    16
# TOTAL_STR._LANDED                            6                    11
# TD_ATT                                       0                     0
# TD_LANDED                                    0                     0
# HEAD_ATT                                     8                    16
# HEAD_LANDED                                  2                    11
# BODY_ATT                                     1                     0
# BODY_LANDED                                  1                     0
# LEG_ATT                                      0                     0
# LEG_LANDED                                   0                     0
# DISTANCE_ATT                                 5                     0
# DISTANCE_LANDED                              1                     0
# CLINCH_ATT                                   4                     3
# CLINCH_LANDED                                2                     2
# GROUND_ATT                                   0                    13
# GROUND_LANDED                                0                     9
# title_bout                                   0                     0
# weight_class                      Middleweight           Heavyweight
# total_time_fought(sec)                     176                    43
# no_of_rounds                                 3                     2
# won                                          0                     1
# age                                    22.9765                    25
#
#                                             4                         5      \
# fighter_name                         David Abbott              David Abbott
# Height                                         72                        72
# Weight                                        265                       265
# Reach                                       73.75                     73.75
# Stance                                     Switch                    Switch
# DOB                           1984-09-26 00:00:00       1984-09-26 00:00:00
# KD                                              0                         1
# SIG_STR_pct                                  0.41                      0.52
# TD_pct                                       0.75                         1
# SUB_ATT                                         0                         0
# PASS                                            1                         1
# REV                                             0                         0
# win_by                       Decision - Unanimous                    KO/TKO
# last_round                                      2                         1
# last_round_time                               180                        63
# date                          1997-12-21 00:00:00       1996-12-07 00:00:00
# location                Yokohama, Kanagawa, Japan  Birmingham, Alabama, USA
# SIG_STR._ATT                                   31                        17
# SIG_STR._LANDED                                13                         9
# TOTAL_STR._ATT                                 90                        21
# TOTAL_STR._LANDED                              69                        13
# TD_ATT                                          4                         1
# TD_LANDED                                       3                         1
# HEAD_ATT                                       31                        17
# HEAD_LANDED                                    13                         9
# BODY_ATT                                        0                         0
# BODY_LANDED                                     0                         0
# LEG_ATT                                         0                         0
# LEG_LANDED                                      0                         0
# DISTANCE_ATT                                   12                         1
# DISTANCE_LANDED                                 6                         1
# CLINCH_ATT                                      0                        16
# CLINCH_LANDED                                   0                         8
# GROUND_ATT                                     19                         0
# GROUND_LANDED                                   7                         0
# title_bout                                      0                         0
# weight_class                          Heavyweight               Open Weight
# total_time_fought(sec)                        900                        63
# no_of_rounds                                    2                         2
# won                                             1                         1
# age                                            25                        25
#
#                                            6                      7      \
# fighter_name                        David Abbott           David Abbott
# Height                                        72                     72
# Weight                                       265                    265
# Reach                                      73.75                  73.75
# Stance                                    Switch                 Switch
# DOB                          1984-09-26 00:00:00    1984-09-26 00:00:00
# KD                                             0                      0
# SIG_STR_pct                                 0.44                   0.88
# TD_pct                                         0                      1
# SUB_ATT                                        1                      1
# PASS                                           1                      1
# REV                                            0                      0
# win_by                                    KO/TKO             Submission
# last_round                                     1                      1
# last_round_time                              171                    126
# date                         1996-12-07 00:00:00    1996-09-20 00:00:00
# location                Birmingham, Alabama, USA  Augusta, Georgia, USA
# SIG_STR._ATT                                   9                      9
# SIG_STR._LANDED                                4                      8
# TOTAL_STR._ATT                                17                     17
# TOTAL_STR._LANDED                              9                     16
# TD_ATT                                         1                      1
# TD_LANDED                                      0                      1
# HEAD_ATT                                       9                      6
# HEAD_LANDED                                    4                      5
# BODY_ATT                                       0                      3
# BODY_LANDED                                    0                      3
# LEG_ATT                                        0                      0
# LEG_LANDED                                     0                      0
# DISTANCE_ATT                                   5                      0
# DISTANCE_LANDED                                1                      0
# CLINCH_ATT                                     0                      0
# CLINCH_LANDED                                  0                      0
# GROUND_ATT                                     4                      9
# GROUND_LANDED                                  3                      8
# title_bout                                     0                      0
# weight_class                         Open Weight            Open Weight
# total_time_fought(sec)                       171                    126
# no_of_rounds                                   2                      1
# won                                            1                      1
# age                                           25                     25
#
#                                         8                     9      ...  \
# fighter_name                     David Abbott          David Abbott  ...
# Height                                     72                    72  ...
# Weight                                    265                   265  ...
# Reach                                   73.75                 73.75  ...
# Stance                                 Switch                Switch  ...
# DOB                       1984-09-26 00:00:00   1984-09-26 00:00:00  ...
# KD                                          0                     0  ...
# SIG_STR_pct                                 1                  0.66  ...
# TD_pct                                      1                     1  ...
# SUB_ATT                                     1                     0  ...
# PASS                                        1                     1  ...
# REV                                         0                     0  ...
# win_by                             Submission                KO/TKO  ...
# last_round                                  1                     1  ...
# last_round_time                            74                   113  ...
# date                      1995-12-16 00:00:00   1995-07-14 00:00:00  ...
# location                Denver, Colorado, USA  Casper, Wyoming, USA  ...
# SIG_STR._ATT                                1                    21  ...
# SIG_STR._LANDED                             1                    14  ...
# TOTAL_STR._ATT                              5                    25  ...
# TOTAL_STR._LANDED                           3                    18  ...
# TD_ATT                                      1                     1  ...
# TD_LANDED                                   1                     1  ...
# HEAD_ATT                                    1                    20  ...
# HEAD_LANDED                                 1                    13  ...
# BODY_ATT                                    0                     1  ...
# BODY_LANDED                                 0                     1  ...
# LEG_ATT                                     0                     0  ...
# LEG_LANDED                                  0                     0  ...
# DISTANCE_ATT                                1                     1  ...
# DISTANCE_LANDED                             1                     1  ...
# CLINCH_ATT                                  0                     0  ...
# CLINCH_LANDED                               0                     0  ...
# GROUND_ATT                                  0                    20  ...
# GROUND_LANDED                               0                    13  ...
# title_bout                                  0                     0  ...
# weight_class                      Open Weight           Open Weight  ...
# total_time_fought(sec)                     74                   113  ...
# no_of_rounds                                1                     1  ...
# won                                         1                     1  ...
# age                                        25                    25  ...
#
#                                          12360                   12361  \
# fighter_name                       Cat Zingano             Cat Zingano
# Height                                      66                      66
# Weight                                     145                     145
# Reach                                       68                      68
# Stance                                Southpaw                Southpaw
# DOB                        1982-07-01 00:00:00     1982-07-01 00:00:00
# KD                                           0                       0
# SIG_STR_pct                               0.47                    0.66
# TD_pct                                    0.75                       1
# SUB_ATT                                      0                       3
# PASS                                         2                       5
# REV                                          2                       0
# win_by                    Decision - Unanimous                  KO/TKO
# last_round                                   3                       3
# last_round_time                            300                      81
# date                       2016-07-09 00:00:00     2014-09-27 00:00:00
# location                Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# SIG_STR._ATT                                23                      60
# SIG_STR._LANDED                             11                      40
# TOTAL_STR._ATT                              37                     116
# TOTAL_STR._LANDED                           23                      93
# TD_ATT                                       4                       3
# TD_LANDED                                    3                       3
# HEAD_ATT                                    18                      49
# HEAD_LANDED                                  6                      31
# BODY_ATT                                     4                       9
# BODY_LANDED                                  4                       7
# LEG_ATT                                      1                       2
# LEG_LANDED                                   1                       2
# DISTANCE_ATT                                12                       5
# DISTANCE_LANDED                              3                       1
# CLINCH_ATT                                   3                       8
# CLINCH_LANDED                                2                       7
# GROUND_ATT                                   8                      47
# GROUND_LANDED                                6                      32
# title_bout                                   0                       0
# weight_class              Women's Bantamweight    Women's Bantamweight
# total_time_fought(sec)                     900                     681
# no_of_rounds                                 3                       3
# won                                          0                       1
# age                                     34.024                 32.2416
#
#                                                12362                   12363  \
# fighter_name                             Cat Zingano             Cat Zingano
# Height                                            66                      66
# Weight                                           145                     145
# Reach                                             68                      68
# Stance                                      Southpaw                Southpaw
# DOB                              1982-07-01 00:00:00     1982-07-01 00:00:00
# KD                                                 0                       0
# SIG_STR_pct                                        0                    0.83
# TD_pct                                             0                       1
# SUB_ATT                                            0                       1
# PASS                                               0                       4
# REV                                                0                       2
# win_by                                    Submission                  KO/TKO
# last_round                                         1                       3
# last_round_time                                   14                     175
# date                             2015-02-28 00:00:00     2013-04-13 00:00:00
# location                Los Angeles, California, USA  Las Vegas, Nevada, USA
# SIG_STR._ATT                                       1                      42
# SIG_STR._LANDED                                    0                      35
# TOTAL_STR._ATT                                     1                     120
# TOTAL_STR._LANDED                                  0                     107
# TD_ATT                                             0                       1
# TD_LANDED                                          0                       1
# HEAD_ATT                                           0                      30
# HEAD_LANDED                                        0                      23
# BODY_ATT                                           1                       8
# BODY_LANDED                                        0                       8
# LEG_ATT                                            0                       4
# LEG_LANDED                                         0                       4
# DISTANCE_ATT                                       1                      22
# DISTANCE_LANDED                                    0                      16
# CLINCH_ATT                                         0                       9
# CLINCH_LANDED                                      0                       8
# GROUND_ATT                                         0                      11
# GROUND_LANDED                                      0                      11
# title_bout                                         1                       0
# weight_class                    Women's Bantamweight    Women's Bantamweight
# total_time_fought(sec)                            14                     775
# no_of_rounds                                       5                       3
# won                                                0                       1
# age                                          32.6632                  30.785
#
#                                               12364                   12365  \
# fighter_name                          Igor Zinoviev           Dave Zitanick
# Height                                           73                 71.0858
# Weight                                          199                     170
# Reach                                       74.7083                  72.018
# Stance                                     Orthodox                Orthodox
# DOB                             1984-09-26 00:00:00     1980-03-05 00:00:00
# KD                                                0                0.215127
# SIG_STR_pct                                       0                0.440723
# TD_pct                                            0                0.275527
# SUB_ATT                                           0                0.422011
# PASS                                              0                 1.10154
# REV                                               0                0.137319
# win_by                                       KO/TKO    Decision - Unanimous
# last_round                                        1                 2.30308
# last_round_time                                  22                 226.129
# date                            1998-03-13 00:00:00     2016-11-19 00:00:00
# location                New Orleans, Louisiana, USA  Las Vegas, Nevada, USA
# SIG_STR._ATT                                      2                 75.7565
# SIG_STR._LANDED                                   0                 32.4959
# TOTAL_STR._ATT                                    2                 96.0553
# TOTAL_STR._LANDED                                 0                 50.5371
# TD_ATT                                            0                 2.80362
# TD_LANDED                                         0                 1.07092
# HEAD_ATT                                          2                 59.4518
# HEAD_LANDED                                       0                 20.6553
# BODY_ATT                                          0                  9.5702
# BODY_LANDED                                       0                 6.51576
# LEG_ATT                                           0                 6.73451
# LEG_LANDED                                        0                 5.32482
# DISTANCE_ATT                                      2                 60.4344
# DISTANCE_LANDED                                   0                 22.1208
# CLINCH_ATT                                        0                 7.67971
# CLINCH_LANDED                                     0                  5.2106
# GROUND_ATT                                        0                 7.64239
# GROUND_LANDED                                     0                 5.16449
# title_bout                                        1                0.063587
# weight_class                      Light Heavyweight             Lightweight
# total_time_fought(sec)                           22                 619.592
# no_of_rounds                                      3                   3.125
# won                                               0                       0
# age                                              25                 36.7099
#
#                                          12366                   12367  \
# fighter_name                       Alex Zuniga           George Zuniga
# Height                                 68.4629                      69
# Weight                                     145                     185
# Reach                                   72.018                 70.8698
# Stance                                Orthodox                Orthodox
# DOB                        1984-09-26 00:00:00     1984-09-26 00:00:00
# KD                                    0.215127                0.215127
# SIG_STR_pct                           0.440723                0.440723
# TD_pct                                0.275527                0.275527
# SUB_ATT                               0.422011                0.422011
# PASS                                   1.10154                 1.10154
# REV                                   0.137319                0.137319
# win_by                    Decision - Unanimous    Decision - Unanimous
# last_round                             2.30308                 2.30308
# last_round_time                        226.129                 226.129
# date                       2016-11-19 00:00:00     2016-11-19 00:00:00
# location                Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# SIG_STR._ATT                           75.7565                 75.7565
# SIG_STR._LANDED                        32.4959                 32.4959
# TOTAL_STR._ATT                         96.0553                 96.0553
# TOTAL_STR._LANDED                      50.5371                 50.5371
# TD_ATT                                 2.80362                 2.80362
# TD_LANDED                              1.07092                 1.07092
# HEAD_ATT                               59.4518                 59.4518
# HEAD_LANDED                            20.6553                 20.6553
# BODY_ATT                                9.5702                  9.5702
# BODY_LANDED                            6.51576                 6.51576
# LEG_ATT                                6.73451                 6.73451
# LEG_LANDED                             5.32482                 5.32482
# DISTANCE_ATT                           60.4344                 60.4344
# DISTANCE_LANDED                        22.1208                 22.1208
# CLINCH_ATT                             7.67971                 7.67971
# CLINCH_LANDED                           5.2106                  5.2106
# GROUND_ATT                             7.64239                 7.64239
# GROUND_LANDED                          5.16449                 5.16449
# title_bout                            0.063587                0.063587
# weight_class                       Lightweight             Lightweight
# total_time_fought(sec)                 619.592                 619.592
# no_of_rounds                             3.125                   3.125
# won                                          0                       0
# age                                    32.1485                 32.1485
#
#                                          12368                   12369
# fighter_name                      Allan Zuniga          Virgil Zwicker
# Height                                      67                      74
# Weight                                     155                     205
# Reach                                       70                      74
# Stance                                Orthodox                Orthodox
# DOB                        1992-04-04 00:00:00     1982-06-26 00:00:00
# KD                                           0                0.215127
# SIG_STR_pct                               0.52                0.440723
# TD_pct                                       0                0.275527
# SUB_ATT                                      1                0.422011
# PASS                                         0                 1.10154
# REV                                          0                0.137319
# win_by                     Decision - Majority    Decision - Unanimous
# last_round                                   3                 2.30308
# last_round_time                            300                 226.129
# date                       2018-07-06 00:00:00     2016-11-19 00:00:00
# location                Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# SIG_STR._ATT                               112                 75.7565
# SIG_STR._LANDED                             59                 32.4959
# TOTAL_STR._ATT                             147                 96.0553
# TOTAL_STR._LANDED                           93                 50.5371
# TD_ATT                                       0                 2.80362
# TD_LANDED                                    0                 1.07092
# HEAD_ATT                                    78                 59.4518
# HEAD_LANDED                                 33                 20.6553
# BODY_ATT                                    24                  9.5702
# BODY_LANDED                                 18                 6.51576
# LEG_ATT                                     10                 6.73451
# LEG_LANDED                                   8                 5.32482
# DISTANCE_ATT                                96                 60.4344
# DISTANCE_LANDED                             44                 22.1208
# CLINCH_ATT                                  15                 7.67971
# CLINCH_LANDED                               14                  5.2106
# GROUND_ATT                                   1                 7.64239
# GROUND_LANDED                                1                 5.16449
# title_bout                                   0                0.063587
# weight_class                       Lightweight             Lightweight
# total_time_fought(sec)                     900                 619.592
# no_of_rounds                                 3                   3.125
# won                                          0                       0
# age                                    26.2538                 34.4018
#
# [41 rows x 12370 columns]

# %%
df_fighter_history.columns

# %%
df_fighter_history.T
# Out:
#                                        0                    1      \
# fighter_name                       Tom Aaron         Danny Abbadi
# Height                               69.5797                   71
# Weight                                   155                  155
# Reach                                     70              72.6813
# Stance                              Orthodox             Orthodox
# DOB                      1978-07-13 00:00:00  1983-07-03 00:00:00
# KD                                  0.215127                    0
# SIG_STR_pct                         0.440723                 0.38
# TD_pct                              0.275527                    0
# SUB_ATT                             0.422011                    0
# PASS                                 1.10154                    0
# REV                                 0.137319                    0
# win_by                  Decision - Unanimous     Decision - Split
# last_round                           2.30308                    3
# last_round_time                      226.129                  300
# date                     2016-11-19 00:00:00  2006-09-23 00:00:00
# location                                   1                    0
# SIG_STR._ATT                         75.7565                  146
# SIG_STR._LANDED                      32.4959                   56
# TOTAL_STR._ATT                       96.0553                  173
# TOTAL_STR._LANDED                    50.5371                   79
# TD_ATT                               2.80362                    0
# TD_LANDED                            1.07092                    0
# HEAD_ATT                             59.4518                  137
# HEAD_LANDED                          20.6553                   49
# BODY_ATT                              9.5702                    9
# BODY_LANDED                          6.51576                    7
# LEG_ATT                              6.73451                    0
# LEG_LANDED                           5.32482                    0
# DISTANCE_ATT                         60.4344                  122
# DISTANCE_LANDED                      22.1208                   41
# CLINCH_ATT                           7.67971                   20
# CLINCH_LANDED                         5.2106                   12
# GROUND_ATT                           7.64239                    4
# GROUND_LANDED                        5.16449                    3
# title_bout                          0.063587                    0
# weight_class                     Lightweight          Lightweight
# total_time_fought(sec)               619.592                  900
# no_of_rounds                           3.125                    3
# won                                        0                    0
# age                                  38.3553              23.2257
#
#                                       2                    3      \
# fighter_name                   Danny Abbadi         David Abbott
# Height                                   71                   72
# Weight                                  155                  265
# Reach                               72.6813                73.75
# Stance                             Orthodox               Switch
# DOB                     1983-07-03 00:00:00  1984-09-26 00:00:00
# KD                                        0                    0
# SIG_STR_pct                            0.33                 0.68
# TD_pct                                    0                    0
# SUB_ATT                                   0                    0
# PASS                                      0                    0
# REV                                       0                    1
# win_by                           Submission               KO/TKO
# last_round                                1                    1
# last_round_time                         176                   43
# date                    2006-06-24 00:00:00  1998-05-15 00:00:00
# location                                  1                    0
# SIG_STR._ATT                              9                   16
# SIG_STR._LANDED                           3                   11
# TOTAL_STR._ATT                           12                   16
# TOTAL_STR._LANDED                         6                   11
# TD_ATT                                    0                    0
# TD_LANDED                                 0                    0
# HEAD_ATT                                  8                   16
# HEAD_LANDED                               2                   11
# BODY_ATT                                  1                    0
# BODY_LANDED                               1                    0
# LEG_ATT                                   0                    0
# LEG_LANDED                                0                    0
# DISTANCE_ATT                              5                    0
# DISTANCE_LANDED                           1                    0
# CLINCH_ATT                                4                    3
# CLINCH_LANDED                             2                    2
# GROUND_ATT                                0                   13
# GROUND_LANDED                             0                    9
# title_bout                                0                    0
# weight_class                   Middleweight          Heavyweight
# total_time_fought(sec)                  176                   43
# no_of_rounds                              3                    2
# won                                       0                    1
# age                                 22.9765                   25
#
#                                        4                    5      \
# fighter_name                    David Abbott         David Abbott
# Height                                    72                   72
# Weight                                   265                  265
# Reach                                  73.75                73.75
# Stance                                Switch               Switch
# DOB                      1984-09-26 00:00:00  1984-09-26 00:00:00
# KD                                         0                    1
# SIG_STR_pct                             0.41                 0.52
# TD_pct                                  0.75                    1
# SUB_ATT                                    0                    0
# PASS                                       1                    1
# REV                                        0                    0
# win_by                  Decision - Unanimous               KO/TKO
# last_round                                 2                    1
# last_round_time                          180                   63
# date                     1997-12-21 00:00:00  1996-12-07 00:00:00
# location                                   0                    0
# SIG_STR._ATT                              31                   17
# SIG_STR._LANDED                           13                    9
# TOTAL_STR._ATT                            90                   21
# TOTAL_STR._LANDED                         69                   13
# TD_ATT                                     4                    1
# TD_LANDED                                  3                    1
# HEAD_ATT                                  31                   17
# HEAD_LANDED                               13                    9
# BODY_ATT                                   0                    0
# BODY_LANDED                                0                    0
# LEG_ATT                                    0                    0
# LEG_LANDED                                 0                    0
# DISTANCE_ATT                              12                    1
# DISTANCE_LANDED                            6                    1
# CLINCH_ATT                                 0                   16
# CLINCH_LANDED                              0                    8
# GROUND_ATT                                19                    0
# GROUND_LANDED                              7                    0
# title_bout                                 0                    0
# weight_class                     Heavyweight          Open Weight
# total_time_fought(sec)                   900                   63
# no_of_rounds                               2                    2
# won                                        1                    1
# age                                       25                   25
#
#                                       6                    7      \
# fighter_name                   David Abbott         David Abbott
# Height                                   72                   72
# Weight                                  265                  265
# Reach                                 73.75                73.75
# Stance                               Switch               Switch
# DOB                     1984-09-26 00:00:00  1984-09-26 00:00:00
# KD                                        0                    0
# SIG_STR_pct                            0.44                 0.88
# TD_pct                                    0                    1
# SUB_ATT                                   1                    1
# PASS                                      1                    1
# REV                                       0                    0
# win_by                               KO/TKO           Submission
# last_round                                1                    1
# last_round_time                         171                  126
# date                    1996-12-07 00:00:00  1996-09-20 00:00:00
# location                                  0                    0
# SIG_STR._ATT                              9                    9
# SIG_STR._LANDED                           4                    8
# TOTAL_STR._ATT                           17                   17
# TOTAL_STR._LANDED                         9                   16
# TD_ATT                                    1                    1
# TD_LANDED                                 0                    1
# HEAD_ATT                                  9                    6
# HEAD_LANDED                               4                    5
# BODY_ATT                                  0                    3
# BODY_LANDED                               0                    3
# LEG_ATT                                   0                    0
# LEG_LANDED                                0                    0
# DISTANCE_ATT                              5                    0
# DISTANCE_LANDED                           1                    0
# CLINCH_ATT                                0                    0
# CLINCH_LANDED                             0                    0
# GROUND_ATT                                4                    9
# GROUND_LANDED                             3                    8
# title_bout                                0                    0
# weight_class                    Open Weight          Open Weight
# total_time_fought(sec)                  171                  126
# no_of_rounds                              2                    1
# won                                       1                    1
# age                                      25                   25
#
#                                       8                    9      ...  \
# fighter_name                   David Abbott         David Abbott  ...
# Height                                   72                   72  ...
# Weight                                  265                  265  ...
# Reach                                 73.75                73.75  ...
# Stance                               Switch               Switch  ...
# DOB                     1984-09-26 00:00:00  1984-09-26 00:00:00  ...
# KD                                        0                    0  ...
# SIG_STR_pct                               1                 0.66  ...
# TD_pct                                    1                    1  ...
# SUB_ATT                                   1                    0  ...
# PASS                                      1                    1  ...
# REV                                       0                    0  ...
# win_by                           Submission               KO/TKO  ...
# last_round                                1                    1  ...
# last_round_time                          74                  113  ...
# date                    1995-12-16 00:00:00  1995-07-14 00:00:00  ...
# location                                  0                    0  ...
# SIG_STR._ATT                              1                   21  ...
# SIG_STR._LANDED                           1                   14  ...
# TOTAL_STR._ATT                            5                   25  ...
# TOTAL_STR._LANDED                         3                   18  ...
# TD_ATT                                    1                    1  ...
# TD_LANDED                                 1                    1  ...
# HEAD_ATT                                  1                   20  ...
# HEAD_LANDED                               1                   13  ...
# BODY_ATT                                  0                    1  ...
# BODY_LANDED                               0                    1  ...
# LEG_ATT                                   0                    0  ...
# LEG_LANDED                                0                    0  ...
# DISTANCE_ATT                              1                    1  ...
# DISTANCE_LANDED                           1                    1  ...
# CLINCH_ATT                                0                    0  ...
# CLINCH_LANDED                             0                    0  ...
# GROUND_ATT                                0                   20  ...
# GROUND_LANDED                             0                   13  ...
# title_bout                                0                    0  ...
# weight_class                    Open Weight          Open Weight  ...
# total_time_fought(sec)                   74                  113  ...
# no_of_rounds                              1                    1  ...
# won                                       1                    1  ...
# age                                      25                   25  ...
#
#                                        12360                 12361  \
# fighter_name                     Cat Zingano           Cat Zingano
# Height                                    66                    66
# Weight                                   145                   145
# Reach                                     68                    68
# Stance                              Southpaw              Southpaw
# DOB                      1982-07-01 00:00:00   1982-07-01 00:00:00
# KD                                         0                     0
# SIG_STR_pct                             0.47                  0.66
# TD_pct                                  0.75                     1
# SUB_ATT                                    0                     3
# PASS                                       2                     5
# REV                                        2                     0
# win_by                  Decision - Unanimous                KO/TKO
# last_round                                 3                     3
# last_round_time                          300                    81
# date                     2016-07-09 00:00:00   2014-09-27 00:00:00
# location                                   1                     1
# SIG_STR._ATT                              23                    60
# SIG_STR._LANDED                           11                    40
# TOTAL_STR._ATT                            37                   116
# TOTAL_STR._LANDED                         23                    93
# TD_ATT                                     4                     3
# TD_LANDED                                  3                     3
# HEAD_ATT                                  18                    49
# HEAD_LANDED                                6                    31
# BODY_ATT                                   4                     9
# BODY_LANDED                                4                     7
# LEG_ATT                                    1                     2
# LEG_LANDED                                 1                     2
# DISTANCE_ATT                              12                     5
# DISTANCE_LANDED                            3                     1
# CLINCH_ATT                                 3                     8
# CLINCH_LANDED                              2                     7
# GROUND_ATT                                 8                    47
# GROUND_LANDED                              6                    32
# title_bout                                 0                     0
# weight_class            Women's Bantamweight  Women's Bantamweight
# total_time_fought(sec)                   900                   681
# no_of_rounds                               3                     3
# won                                        0                     1
# age                                   34.024               32.2416
#
#                                        12362                 12363  \
# fighter_name                     Cat Zingano           Cat Zingano
# Height                                    66                    66
# Weight                                   145                   145
# Reach                                     68                    68
# Stance                              Southpaw              Southpaw
# DOB                      1982-07-01 00:00:00   1982-07-01 00:00:00
# KD                                         0                     0
# SIG_STR_pct                                0                  0.83
# TD_pct                                     0                     1
# SUB_ATT                                    0                     1
# PASS                                       0                     4
# REV                                        0                     2
# win_by                            Submission                KO/TKO
# last_round                                 1                     3
# last_round_time                           14                   175
# date                     2015-02-28 00:00:00   2013-04-13 00:00:00
# location                                   0                     1
# SIG_STR._ATT                               1                    42
# SIG_STR._LANDED                            0                    35
# TOTAL_STR._ATT                             1                   120
# TOTAL_STR._LANDED                          0                   107
# TD_ATT                                     0                     1
# TD_LANDED                                  0                     1
# HEAD_ATT                                   0                    30
# HEAD_LANDED                                0                    23
# BODY_ATT                                   1                     8
# BODY_LANDED                                0                     8
# LEG_ATT                                    0                     4
# LEG_LANDED                                 0                     4
# DISTANCE_ATT                               1                    22
# DISTANCE_LANDED                            0                    16
# CLINCH_ATT                                 0                     9
# CLINCH_LANDED                              0                     8
# GROUND_ATT                                 0                    11
# GROUND_LANDED                              0                    11
# title_bout                                 1                     0
# weight_class            Women's Bantamweight  Women's Bantamweight
# total_time_fought(sec)                    14                   775
# no_of_rounds                               5                     3
# won                                        0                     1
# age                                  32.6632                30.785
#
#                                       12364                 12365  \
# fighter_name                  Igor Zinoviev         Dave Zitanick
# Height                                   73               71.0858
# Weight                                  199                   170
# Reach                               74.7083                72.018
# Stance                             Orthodox              Orthodox
# DOB                     1984-09-26 00:00:00   1980-03-05 00:00:00
# KD                                        0              0.215127
# SIG_STR_pct                               0              0.440723
# TD_pct                                    0              0.275527
# SUB_ATT                                   0              0.422011
# PASS                                      0               1.10154
# REV                                       0              0.137319
# win_by                               KO/TKO  Decision - Unanimous
# last_round                                1               2.30308
# last_round_time                          22               226.129
# date                    1998-03-13 00:00:00   2016-11-19 00:00:00
# location                                  0                     1
# SIG_STR._ATT                              2               75.7565
# SIG_STR._LANDED                           0               32.4959
# TOTAL_STR._ATT                            2               96.0553
# TOTAL_STR._LANDED                         0               50.5371
# TD_ATT                                    0               2.80362
# TD_LANDED                                 0               1.07092
# HEAD_ATT                                  2               59.4518
# HEAD_LANDED                               0               20.6553
# BODY_ATT                                  0                9.5702
# BODY_LANDED                               0               6.51576
# LEG_ATT                                   0               6.73451
# LEG_LANDED                                0               5.32482
# DISTANCE_ATT                              2               60.4344
# DISTANCE_LANDED                           0               22.1208
# CLINCH_ATT                                0               7.67971
# CLINCH_LANDED                             0                5.2106
# GROUND_ATT                                0               7.64239
# GROUND_LANDED                             0               5.16449
# title_bout                                1              0.063587
# weight_class              Light Heavyweight           Lightweight
# total_time_fought(sec)                   22               619.592
# no_of_rounds                              3                 3.125
# won                                       0                     0
# age                                      25               36.7099
#
#                                        12366                 12367  \
# fighter_name                     Alex Zuniga         George Zuniga
# Height                               68.4629                    69
# Weight                                   145                   185
# Reach                                 72.018               70.8698
# Stance                              Orthodox              Orthodox
# DOB                      1984-09-26 00:00:00   1984-09-26 00:00:00
# KD                                  0.215127              0.215127
# SIG_STR_pct                         0.440723              0.440723
# TD_pct                              0.275527              0.275527
# SUB_ATT                             0.422011              0.422011
# PASS                                 1.10154               1.10154
# REV                                 0.137319              0.137319
# win_by                  Decision - Unanimous  Decision - Unanimous
# last_round                           2.30308               2.30308
# last_round_time                      226.129               226.129
# date                     2016-11-19 00:00:00   2016-11-19 00:00:00
# location                                   1                     1
# SIG_STR._ATT                         75.7565               75.7565
# SIG_STR._LANDED                      32.4959               32.4959
# TOTAL_STR._ATT                       96.0553               96.0553
# TOTAL_STR._LANDED                    50.5371               50.5371
# TD_ATT                               2.80362               2.80362
# TD_LANDED                            1.07092               1.07092
# HEAD_ATT                             59.4518               59.4518
# HEAD_LANDED                          20.6553               20.6553
# BODY_ATT                              9.5702                9.5702
# BODY_LANDED                          6.51576               6.51576
# LEG_ATT                              6.73451               6.73451
# LEG_LANDED                           5.32482               5.32482
# DISTANCE_ATT                         60.4344               60.4344
# DISTANCE_LANDED                      22.1208               22.1208
# CLINCH_ATT                           7.67971               7.67971
# CLINCH_LANDED                         5.2106                5.2106
# GROUND_ATT                           7.64239               7.64239
# GROUND_LANDED                        5.16449               5.16449
# title_bout                          0.063587              0.063587
# weight_class                     Lightweight           Lightweight
# total_time_fought(sec)               619.592               619.592
# no_of_rounds                           3.125                 3.125
# won                                        0                     0
# age                                  32.1485               32.1485
#
#                                       12368                 12369
# fighter_name                   Allan Zuniga        Virgil Zwicker
# Height                                   67                    74
# Weight                                  155                   205
# Reach                                    70                    74
# Stance                             Orthodox              Orthodox
# DOB                     1992-04-04 00:00:00   1982-06-26 00:00:00
# KD                                        0              0.215127
# SIG_STR_pct                            0.52              0.440723
# TD_pct                                    0              0.275527
# SUB_ATT                                   1              0.422011
# PASS                                      0               1.10154
# REV                                       0              0.137319
# win_by                  Decision - Majority  Decision - Unanimous
# last_round                                3               2.30308
# last_round_time                         300               226.129
# date                    2018-07-06 00:00:00   2016-11-19 00:00:00
# location                                  1                     1
# SIG_STR._ATT                            112               75.7565
# SIG_STR._LANDED                          59               32.4959
# TOTAL_STR._ATT                          147               96.0553
# TOTAL_STR._LANDED                        93               50.5371
# TD_ATT                                    0               2.80362
# TD_LANDED                                 0               1.07092
# HEAD_ATT                                 78               59.4518
# HEAD_LANDED                              33               20.6553
# BODY_ATT                                 24                9.5702
# BODY_LANDED                              18               6.51576
# LEG_ATT                                  10               6.73451
# LEG_LANDED                                8               5.32482
# DISTANCE_ATT                             96               60.4344
# DISTANCE_LANDED                          44               22.1208
# CLINCH_ATT                               15               7.67971
# CLINCH_LANDED                            14                5.2106
# GROUND_ATT                                1               7.64239
# GROUND_LANDED                             1               5.16449
# title_bout                                0              0.063587
# weight_class                    Lightweight           Lightweight
# total_time_fought(sec)                  900               619.592
# no_of_rounds                              3                 3.125
# won                                       0                     0
# age                                 26.2538               34.4018
#
# [41 rows x 12370 columns]

# %%
df_fighter_history['win_by'].value_counts()
# Out:
# Decision - Unanimous       5115
# KO/TKO                     3517
# Submission                 2260
# Decision - Split           1066
# TKO - Doctor's Stoppage     148
# Decision - Majority         122
# Overturned                   74
# DQ                           34
# Could Not Continue           30
# Other                         4
# Name: win_by, dtype: int64
